# %%
# just importing a random selection of things; we can fix this later
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import sklearn.metrics as metrics
from sklearn.model_selection import cross_val_score
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.linear_model import LinearRegression, LogisticRegressionCV
# %matplotlib inline

from sklearn.tree import DecisionTreeRegressor

from sklearn.model_selection import cross_val_score

from sklearn.metrics import accuracy_score
from sklearn.model_selection import KFold
from sklearn.grid_search import GridSearchCV

from pprint import pprint 

from sklearn.ensemble import BaggingClassifier
from sklearn import model_selection
from random import seed
from sklearn.model_selection import cross_val_predict

from sklearn.ensemble import RandomForestClassifier
from itertools import product
from collections import OrderedDict
from itertools import product

from sklearn import model_selection
from sklearn.svm import SVC
from sklearn import neighbors
from sklearn.ensemble import VotingClassifier

from sklearn.model_selection import train_test_split
from __future__ import print_function # For Python 2 / 3 compatability
from sklearn.metrics import confusion_matrix
import itertools

import json
from copy import copy

import warnings
from sklearn import preprocessing
# %autosave 300
warnings.filterwarnings("ignore")
# Out:
# Autosaving every 300 seconds

# %% [markdown]
# # Data Cleaning and Preliminary Exploration

# %% [markdown]
# ## Preliminary Exploration

# %%
# load ADNIMERGE.csv, the main dataset (we will add our own variables to it). 
ADNI_merge = pd.read_csv('ADNIMERGE.csv')
ADNI_merge.head()
# Out:
#    RID        PTID VISCODE  SITE COLPROT ORIGPROT    EXAMDATE DX_bl   AGE  \
# 0    2  011_S_0002      bl    11   ADNI1    ADNI1  2005-09-08    CN  74.3
# 1    3  011_S_0003      bl    11   ADNI1    ADNI1  2005-09-12    AD  81.3
# 2    3  011_S_0003     m06    11   ADNI1    ADNI1  2006-03-13    AD  81.3
# 3    3  011_S_0003     m12    11   ADNI1    ADNI1  2006-09-12    AD  81.3
# 4    3  011_S_0003     m24    11   ADNI1    ADNI1  2007-09-12    AD  81.3
#
#   PTGENDER          ...            EcogSPDivatt_bl EcogSPTotal_bl   FDG_bl  \
# 0     Male          ...                        NaN            NaN  1.36926
# 1     Male          ...                        NaN            NaN  1.09079
# 2     Male          ...                        NaN            NaN  1.09079
# 3     Male          ...                        NaN            NaN  1.09079
# 4     Male          ...                        NaN            NaN  1.09079
#
#   PIB_bl  AV45_bl  Years_bl  Month_bl  Month   M           update_stamp
# 0    NaN      NaN  0.000000   0.00000      0   0  2017-08-13 23:50:48.0
# 1    NaN      NaN  0.000000   0.00000      0   0  2017-08-13 23:50:48.0
# 2    NaN      NaN  0.498289   5.96721      6   6  2017-08-13 23:50:48.0
# 3    NaN      NaN  0.999316  11.96720     12  12  2017-08-13 23:50:48.0
# 4    NaN      NaN  1.998630  23.93440     24  24  2017-08-13 23:50:48.0
#
# [5 rows x 94 columns]

# %% [markdown]
# #### NOTE: this is new code (11.23.17) because missing values are also denoted by "-4" and "-1".
# #### Please see the training powerpoint for more info: https://adni.loni.usc.edu/wp-content/uploads/2012/08/slide_data_training_part2_reduced-size.pdf

# %%
''' ADNI2 data within ADNIMERGE.csv '''
# select only the rows that correspond to ADN2
ADNI2= ADNI_merge[ADNI_merge['COLPROT']=='ADNI2']
print(ADNI2.shape)
ADNI2.head()
# Out:
# (6937, 94)
#      RID        PTID VISCODE  SITE COLPROT ORIGPROT    EXAMDATE DX_bl   AGE  \
# 58  5282  082_S_5282      bl    82   ADNI2    ADNI2  2013-09-09   SMC  66.9
# 59  5280  100_S_5280     m24   100   ADNI2    ADNI2  2015-09-29   SMC  67.5
# 68  5280  100_S_5280     m06   100   ADNI2    ADNI2  2014-03-06   SMC  67.5
# 91  5280  100_S_5280      bl   100   ADNI2    ADNI2  2013-09-17   SMC  67.5
# 92  5279  082_S_5279      bl    82   ADNI2    ADNI2  2013-10-23   SMC  68.5
#
#    PTGENDER          ...            EcogSPDivatt_bl EcogSPTotal_bl   FDG_bl  \
# 58     Male          ...                    1.00000        1.25641  1.13549
# 59     Male          ...                    1.00000        1.25000  1.25195
# 68     Male          ...                    1.00000        1.25000  1.25195
# 91     Male          ...                    1.00000        1.25000  1.25195
# 92     Male          ...                    1.33333        1.37838  1.50629
#
#    PIB_bl   AV45_bl  Years_bl  Month_bl  Month   M           update_stamp
# 58    NaN  1.326790  0.000000   0.00000      0   0  2017-10-06 23:20:00.0
# 59    NaN  0.983143  2.031490  24.32790     24  24  2017-10-06 23:20:00.0
# 68    NaN  0.983143  0.465435   5.57377      6   6  2017-10-06 23:20:00.0
# 91    NaN  0.983143  0.000000   0.00000      0   0  2017-10-06 23:20:00.0
# 92    NaN  0.985156  0.000000   0.00000      0   0  2017-10-06 23:20:00.0
#
# [5 rows x 94 columns]

# %%
# It seems there were some 'unknown'..I replaced them with nan
import numpy as np
ADNI2 = ADNI2.replace('Unknown', np.nan)

# %%
# calculate the % of each column that is NaNs and print in descending order
nan_series = (ADNI2.isnull().sum()/len(ADNI2['DX_bl'])).sort_values(ascending=False)
print(nan_series)
# Out:
# PIB                         1.000000
# PIB_bl                      0.992936
# FDG                         0.806833
# AV45                        0.726251
# FLDSTRENG                   0.553986
# MidTemp                     0.543895
# Fusiform                    0.543895
# Entorhinal                  0.543895
# Ventricles                  0.500793
# Hippocampus                 0.497189
# WholeBrain                  0.472106
# FSVERSION                   0.441401
# ICV                         0.441401
# EcogSPOrgan                 0.363269
# EcogPtOrgan                 0.356927
# EcogSPDivatt                0.352314
# MOCA                        0.350584
# RAVLT_perc_forgetting       0.349575
# EcogPtVisspat               0.347268
# EcogPtDivatt                0.346836
# EcogSPVisspat               0.346259
# RAVLT_forgetting            0.345827
# RAVLT_learning              0.344385
# RAVLT_immediate             0.344385
# EcogPtPlan                  0.342944
# EcogSPPlan                  0.342655
# EcogPtLang                  0.341790
# ADAS13                      0.341646
# DX                          0.341502
# EcogPtTotal                 0.341214
#                               ...
# ADAS13_bl                   0.005045
# PTMARRY                     0.004613
# PTETHCAT                    0.004325
# RAVLT_perc_forgetting_bl    0.003316
# FAQ_bl                      0.002883
# RAVLT_immediate_bl          0.002451
# RAVLT_forgetting_bl         0.002451
# RAVLT_learning_bl           0.002451
# ADAS11_bl                   0.002306
# PTRACCAT                    0.001730
# APOE4                       0.001586
# COLPROT                     0.000000
# ORIGPROT                    0.000000
# EXAMDATE                    0.000000
# SITE                        0.000000
# VISCODE                     0.000000
# PTID                        0.000000
# PTGENDER                    0.000000
# DX_bl                       0.000000
# AGE                         0.000000
# update_stamp                0.000000
# PTEDUCAT                    0.000000
# M                           0.000000
# EXAMDATE_bl                 0.000000
# CDRSB_bl                    0.000000
# MMSE_bl                     0.000000
# Years_bl                    0.000000
# Month_bl                    0.000000
# Month                       0.000000
# RID                         0.000000
# Length: 94, dtype: float64

# %%
# calculate the % of each column that is -1 and print in descending order
minus_one_series = (ADNI2[ADNI2 == -1].count()/len(ADNI2['DX_bl'])).sort_values(ascending=False)
print(minus_one_series)
# Out:
# RAVLT_forgetting_bl         0.012830
# RAVLT_learning              0.009658
# RAVLT_learning_bl           0.008217
# RAVLT_forgetting            0.007496
# EcogSPTotal                 0.000000
# EcogSPDivatt                0.000000
# RAVLT_perc_forgetting       0.000000
# FAQ                         0.000000
# MOCA                        0.000000
# EcogPtMem                   0.000000
# EcogPtLang                  0.000000
# EcogPtVisspat               0.000000
# EcogPtPlan                  0.000000
# EcogPtOrgan                 0.000000
# FSVERSION                   0.000000
# FLDSTRENG                   0.000000
# Hippocampus                 0.000000
# EcogPtTotal                 0.000000
# EcogSPMem                   0.000000
# EcogSPLang                  0.000000
# EcogSPVisspat               0.000000
# EcogSPPlan                  0.000000
# EcogSPOrgan                 0.000000
# EcogPtDivatt                0.000000
# update_stamp                0.000000
# RAVLT_immediate             0.000000
# PTEDUCAT                    0.000000
# PTID                        0.000000
# VISCODE                     0.000000
# SITE                        0.000000
#                               ...
# FDG_bl                      0.000000
# PIB_bl                      0.000000
# AV45_bl                     0.000000
# Years_bl                    0.000000
# Month_bl                    0.000000
# Month                       0.000000
# EcogPtMem_bl                0.000000
# ICV_bl                      0.000000
# Entorhinal                  0.000000
# MidTemp_bl                  0.000000
# Fusiform                    0.000000
# MidTemp                     0.000000
# ICV                         0.000000
# DX                          0.000000
# EXAMDATE_bl                 0.000000
# CDRSB_bl                    0.000000
# ADAS11_bl                   0.000000
# ADAS13_bl                   0.000000
# MMSE_bl                     0.000000
# RAVLT_immediate_bl          0.000000
# RAVLT_perc_forgetting_bl    0.000000
# FAQ_bl                      0.000000
# FLDSTRENG_bl                0.000000
# FSVERSION_bl                0.000000
# Ventricles_bl               0.000000
# Hippocampus_bl              0.000000
# WholeBrain_bl               0.000000
# Entorhinal_bl               0.000000
# Fusiform_bl                 0.000000
# RID                         0.000000
# Length: 94, dtype: float64

# %%
# calculate the % of each column that is -4 and print in descending order
minus_one_series = (ADNI2[ADNI2 == -4].count()/len(ADNI2['DX_bl'])).sort_values(ascending=False)
print(minus_one_series)
# Out:
# RAVLT_forgetting            0.000288
# RAVLT_learning              0.000288
# RAVLT_forgetting_bl         0.000144
# EcogPtDivatt                0.000000
# RAVLT_perc_forgetting       0.000000
# FAQ                         0.000000
# MOCA                        0.000000
# EcogPtMem                   0.000000
# EcogPtLang                  0.000000
# EcogPtVisspat               0.000000
# EcogPtPlan                  0.000000
# EcogPtOrgan                 0.000000
# update_stamp                0.000000
# EcogSPMem                   0.000000
# EcogSPLang                  0.000000
# EcogSPVisspat               0.000000
# EcogSPPlan                  0.000000
# EcogSPOrgan                 0.000000
# EcogSPDivatt                0.000000
# EcogSPTotal                 0.000000
# FLDSTRENG                   0.000000
# FSVERSION                   0.000000
# EcogPtTotal                 0.000000
# RAVLT_immediate             0.000000
# Hippocampus                 0.000000
# PTEDUCAT                    0.000000
# PTID                        0.000000
# VISCODE                     0.000000
# SITE                        0.000000
# COLPROT                     0.000000
#                               ...
# FDG_bl                      0.000000
# PIB_bl                      0.000000
# AV45_bl                     0.000000
# Years_bl                    0.000000
# Month_bl                    0.000000
# Month                       0.000000
# MOCA_bl                     0.000000
# ICV_bl                      0.000000
# MidTemp_bl                  0.000000
# Fusiform_bl                 0.000000
# Fusiform                    0.000000
# MidTemp                     0.000000
# ICV                         0.000000
# DX                          0.000000
# EXAMDATE_bl                 0.000000
# CDRSB_bl                    0.000000
# ADAS11_bl                   0.000000
# ADAS13_bl                   0.000000
# MMSE_bl                     0.000000
# RAVLT_immediate_bl          0.000000
# RAVLT_learning_bl           0.000000
# RAVLT_perc_forgetting_bl    0.000000
# FAQ_bl                      0.000000
# FLDSTRENG_bl                0.000000
# FSVERSION_bl                0.000000
# Ventricles_bl               0.000000
# Hippocampus_bl              0.000000
# WholeBrain_bl               0.000000
# Entorhinal_bl               0.000000
# RID                         0.000000
# Length: 94, dtype: float64

# %% [markdown]
# #### Notes
# - Our pure dataframe is called ADNI2

# %% [markdown]
# ## Removing All Missing Data

# %%
ADNI2_remove_all_missing = copy(ADNI2)
for column in ADNI2_remove_all_missing.columns:
    if ADNI2_remove_all_missing[column].isnull().any():
        ADNI2_remove_all_missing = ADNI2_remove_all_missing.drop(labels=column, axis=1)

# %%
ADNI2_remove_all_missing.head()
# Out:
#      RID        PTID VISCODE  SITE COLPROT ORIGPROT    EXAMDATE DX_bl   AGE  \
# 58  5282  082_S_5282      bl    82   ADNI2    ADNI2  2013-09-09   SMC  66.9
# 59  5280  100_S_5280     m24   100   ADNI2    ADNI2  2015-09-29   SMC  67.5
# 68  5280  100_S_5280     m06   100   ADNI2    ADNI2  2014-03-06   SMC  67.5
# 91  5280  100_S_5280      bl   100   ADNI2    ADNI2  2013-09-17   SMC  67.5
# 92  5279  082_S_5279      bl    82   ADNI2    ADNI2  2013-10-23   SMC  68.5
#
#    PTGENDER  PTEDUCAT EXAMDATE_bl  CDRSB_bl  MMSE_bl  Years_bl  Month_bl  \
# 58     Male        17  2013-09-09       0.0       29  0.000000   0.00000
# 59     Male        16  2013-09-17       0.0       30  2.031490  24.32790
# 68     Male        16  2013-09-17       0.0       30  0.465435   5.57377
# 91     Male        16  2013-09-17       0.0       30  0.000000   0.00000
# 92     Male        20  2013-10-23       0.0       30  0.000000   0.00000
#
#     Month   M           update_stamp
# 58      0   0  2017-10-06 23:20:00.0
# 59     24  24  2017-10-06 23:20:00.0
# 68      6   6  2017-10-06 23:20:00.0
# 91      0   0  2017-10-06 23:20:00.0
# 92      0   0  2017-10-06 23:20:00.0

# %%
ADNI2_remove_all_missing.shape
# Out:
# (6937, 19)

# %%
ADNI2_remove_all_missing.columns
# Out:
# Index(['RID', 'PTID', 'VISCODE', 'SITE', 'COLPROT', 'ORIGPROT', 'EXAMDATE',
#        'DX_bl', 'AGE', 'PTGENDER', 'PTEDUCAT', 'EXAMDATE_bl', 'CDRSB_bl',
#        'MMSE_bl', 'Years_bl', 'Month_bl', 'Month', 'M', 'update_stamp'],
#       dtype='object')

# %%
categorical_predictors = ['VISCODE', 'PTGENDER', 'PTEDUCAT']
continuous_predictors = ['RID', 'PTID', 'SITE', 'COLPROT', 'ORIGPROT', 'EXAMDATE', 'DX_bl', 'AGE', 
                         'EXAMDATE_bl', 'CDRSB_bl', 'MMSE_bl', 'Years_bl', 'Month_bl', 'Month', 
                         'M', 'update_stamp']
#dataframe_list = []
categorical_columns_g2cols = ['PTGENDER']                                 
ADNI2_remove_all_missing_clean  = pd.get_dummies(ADNI2_remove_all_missing, columns=categorical_columns_g2cols, prefix = categorical_columns_g2cols , drop_first=False)
# for i in range(len(categorical_predictors)):
#     dummy_frame = pd.get_dummies(ADNI2[categorical_predictors[i]])
#     # The commemted line below could be adjust, I just want to make the columns name clearer
#     #dummy_frame = dummy_frame.iloc[:, :-1]
#     dataframe_list.append(dummy_frame)
# ADNI2_categorical = pd.concat(dataframe_list, axis=1)
# ADNI2_remove_all_missing_clean = pd.concat([ADNI2_remove_all_missing[continuous_predictors], \
                                            #ADNI2_categorical], axis=1)

# %%
print(ADNI2_remove_all_missing_clean.shape)
ADNI2_remove_all_missing_clean.head()
# Out:
# (6937, 20)
#      RID        PTID VISCODE  SITE COLPROT ORIGPROT    EXAMDATE DX_bl   AGE  \
# 58  5282  082_S_5282      bl    82   ADNI2    ADNI2  2013-09-09   SMC  66.9
# 59  5280  100_S_5280     m24   100   ADNI2    ADNI2  2015-09-29   SMC  67.5
# 68  5280  100_S_5280     m06   100   ADNI2    ADNI2  2014-03-06   SMC  67.5
# 91  5280  100_S_5280      bl   100   ADNI2    ADNI2  2013-09-17   SMC  67.5
# 92  5279  082_S_5279      bl    82   ADNI2    ADNI2  2013-10-23   SMC  68.5
#
#     PTEDUCAT EXAMDATE_bl  CDRSB_bl  MMSE_bl  Years_bl  Month_bl  Month   M  \
# 58        17  2013-09-09       0.0       29  0.000000   0.00000      0   0
# 59        16  2013-09-17       0.0       30  2.031490  24.32790     24  24
# 68        16  2013-09-17       0.0       30  0.465435   5.57377      6   6
# 91        16  2013-09-17       0.0       30  0.000000   0.00000      0   0
# 92        20  2013-10-23       0.0       30  0.000000   0.00000      0   0
#
#              update_stamp  PTGENDER_Female  PTGENDER_Male
# 58  2017-10-06 23:20:00.0                0              1
# 59  2017-10-06 23:20:00.0                0              1
# 68  2017-10-06 23:20:00.0                0              1
# 91  2017-10-06 23:20:00.0                0              1
# 92  2017-10-06 23:20:00.0                0              1

# %%
ADNI2_remove_all_missing_clean.columns
# Out:
#  '2017-08-13 23:50:52.0' '2017-08-22 23:12:32.0' '2017-10-06 23:19:46.0'
#  '2017-08-13 23:50:51.0' '2017-10-06 23:19:45.0' '2017-08-13 23:50:50.0'
#  '2017-10-06 23:19:44.0' '2017-08-13 23:50:49.0' '2017-08-22 23:12:30.0'
#  '2017-10-06 23:19:43.0' '2017-08-22 23:12:29.0' '2017-08-13 23:50:48.0'
#  '2017-09-25 00:26:05.0']

# %%
ADNI2.columns
# Out:
# Index(['RID', 'PTID', 'VISCODE', 'SITE', 'COLPROT', 'ORIGPROT', 'EXAMDATE',
#        'DX_bl', 'AGE', 'PTGENDER', 'PTEDUCAT', 'PTETHCAT', 'PTRACCAT',
#        'PTMARRY', 'APOE4', 'FDG', 'PIB', 'AV45', 'CDRSB', 'ADAS11', 'ADAS13',
#        'MMSE', 'RAVLT_immediate', 'RAVLT_learning', 'RAVLT_forgetting',
#        'RAVLT_perc_forgetting', 'FAQ', 'MOCA', 'EcogPtMem', 'EcogPtLang',
#        'EcogPtVisspat', 'EcogPtPlan', 'EcogPtOrgan', 'EcogPtDivatt',
#        'EcogPtTotal', 'EcogSPMem', 'EcogSPLang', 'EcogSPVisspat', 'EcogSPPlan',
#        'EcogSPOrgan', 'EcogSPDivatt', 'EcogSPTotal', 'FLDSTRENG', 'FSVERSION',
#        'Ventricles', 'Hippocampus', 'WholeBrain', 'Entorhinal', 'Fusiform',
#        'MidTemp', 'ICV', 'DX', 'EXAMDATE_bl', 'CDRSB_bl', 'ADAS11_bl',
#        'ADAS13_bl', 'MMSE_bl', 'RAVLT_immediate_bl', 'RAVLT_learning_bl',
#        'RAVLT_forgetting_bl', 'RAVLT_perc_forgetting_bl', 'FAQ_bl',
#        'FLDSTRENG_bl', 'FSVERSION_bl', 'Ventricles_bl', 'Hippocampus_bl',
#        'WholeBrain_bl', 'Entorhinal_bl', 'Fusiform_bl', 'MidTemp_bl', 'ICV_bl',
#        'MOCA_bl', 'EcogPtMem_bl', 'EcogPtLang_bl', 'EcogPtVisspat_bl',
#        'EcogPtPlan_bl', 'EcogPtOrgan_bl', 'EcogPtDivatt_bl', 'EcogPtTotal_bl',
#        'EcogSPMem_bl', 'EcogSPLang_bl', 'EcogSPVisspat_bl', 'EcogSPPlan_bl',
#        'EcogSPOrgan_bl', 'EcogSPDivatt_bl', 'EcogSPTotal_bl', 'FDG_bl',
#        'PIB_bl', 'AV45_bl', 'Years_bl', 'Month_bl', 'Month', 'M',
#        'update_stamp'],
#       dtype='object')

# %%
all_predictors = ['VISCODE','DX_bl', 'AGE', 'PTGENDER', 'PTEDUCAT', 'PTETHCAT', 'PTRACCAT', 'PTMARRY', 'APOE4',
                  'FDG', 'PIB', 'AV45', 'CDRSB', 'ADAS11', 'ADAS13', 'MMSE', 'RAVLT_immediate', 
                  'RAVLT_learning', 'RAVLT_forgetting', 'RAVLT_perc_forgetting', 'FAQ', 'MOCA', 'EcogPtMem', 
                  'EcogPtLang', 'EcogPtVisspat', 'EcogPtPlan', 'EcogPtOrgan', 'EcogPtDivatt', 'EcogPtTotal', 
                  'EcogSPMem', 'EcogSPLang', 'EcogSPVisspat', 'EcogSPPlan', 'EcogSPOrgan', 'EcogSPDivatt', 
                  'EcogSPTotal', 'FLDSTRENG', 'FSVERSION', 'Ventricles', 'Hippocampus', 'WholeBrain', 
                  'Entorhinal', 'Fusiform', 'MidTemp', 'ICV', 'DX', 'EXAMDATE_bl', 'CDRSB_bl', 'ADAS11_bl', 
                  'ADAS13_bl', 'MMSE_bl', 'RAVLT_immediate_bl', 'RAVLT_learning_bl', 'RAVLT_forgetting_bl', 
                  'RAVLT_perc_forgetting_bl', 'FAQ_bl', 'FLDSTRENG_bl', 'FSVERSION_bl', 'Ventricles_bl', 
                  'Hippocampus_bl', 'WholeBrain_bl', 'Entorhinal_bl', 'Fusiform_bl', 'MidTemp_bl', 'ICV_bl',
                  'MOCA_bl', 'EcogPtMem_bl', 'EcogPtLang_bl', 'EcogPtVisspat_bl', 'EcogPtPlan_bl', 'EcogPtOrgan_bl', 
                  'EcogPtDivatt_bl', 'EcogPtTotal_bl', 'EcogSPMem_bl', 'EcogSPLang_bl', 'EcogSPVisspat_bl', 
                  'EcogSPPlan_bl', 'EcogSPOrgan_bl', 'EcogSPDivatt_bl', 'EcogSPTotal_bl', 'FDG_bl', 'PIB_bl', 
                  'AV45_bl', 'Years_bl']
continuous_predictors = ['AGE',
                  'FDG', 'AV45', 'CDRSB', 'ADAS11', 'ADAS13', 'MMSE', 'RAVLT_immediate', 
                  'RAVLT_learning', 'RAVLT_forgetting', 'RAVLT_perc_forgetting', 'FAQ', 'MOCA', 'EcogPtMem', 
                  'EcogPtLang', 'EcogPtVisspat', 'EcogPtPlan', 'EcogPtOrgan', 'EcogPtDivatt', 'EcogPtTotal', 
                  'EcogSPMem', 'EcogSPLang', 'EcogSPVisspat', 'EcogSPPlan', 'EcogSPOrgan', 'EcogSPDivatt', 
                  'EcogSPTotal', 'Ventricles', 'Hippocampus', 'WholeBrain', 
                  'Entorhinal', 'Fusiform', 'MidTemp', 'ICV', 'CDRSB_bl', 'ADAS11_bl', 
                  'ADAS13_bl', 'MMSE_bl', 'RAVLT_immediate_bl', 'RAVLT_learning_bl', 'RAVLT_forgetting_bl', 
                  'RAVLT_perc_forgetting_bl', 'FAQ_bl', 'Ventricles_bl', 
                  'Hippocampus_bl', 'WholeBrain_bl', 'Entorhinal_bl', 'Fusiform_bl', 'MidTemp_bl', 'ICV_bl',
                  'MOCA_bl', 'EcogPtMem_bl', 'EcogPtLang_bl', 'EcogPtVisspat_bl', 'EcogPtPlan_bl', 'EcogPtOrgan_bl', 
                  'EcogPtDivatt_bl', 'EcogPtTotal_bl', 'EcogSPMem_bl', 'EcogSPLang_bl', 'EcogSPVisspat_bl', 
                  'EcogSPPlan_bl', 'EcogSPOrgan_bl', 'EcogSPDivatt_bl', 'EcogSPTotal_bl', 'FDG_bl', 
                  'AV45_bl', 'Years_bl']

# %%
''' Pre-Processing the Missing Categorical Data '''
categorical_predictors = ['DX_bl', 'VISCODE','PTGENDER', 'PTETHCAT', 'PTRACCAT', 'PTMARRY', 'APOE4', 'FLDSTRENG', 'FSVERSION',
                          'DX']



''' Remove all categorical data with nan (only ~0.5%) '''
missing_rows = np.nonzero(np.sum(ADNI2[categorical_predictors].isnull(), axis=1))
ADNI2_categorical_clean = ADNI2.drop(ADNI2.index[missing_rows[0]])

''' Hot-One Encoding of Categorical Predictors '''
# dataframe_list = []
# for i in range(len(categorical_predictors)):
#     dummy_frame = pd.get_dummies(ADNI2[categorical_predictors[i]])
#     # The commemted line below could be adjust, I just want to make the columns name clearer
#     #dummy_frame = dummy_frame.iloc[:, :-1]
#     dataframe_list.append(dummy_frame)


# ADNI2_categorical = pd.concat(dataframe_list, axis=1)
# ADNI2_categorical.rename(columns={0: "APOE4_1", 1: "APOE4_2"}, inplace=True);

ADNI2_categorical = pd.get_dummies(ADNI2[categorical_predictors] , columns=categorical_predictors, prefix = categorical_predictors , drop_first=False)

# %%
ADNI2_categorical.head()
# Out:
#     DX_bl_AD  DX_bl_CN  DX_bl_EMCI  DX_bl_LMCI  DX_bl_SMC  VISCODE_bl  \
# 58         0         0           0           0          1           1
# 59         0         0           0           0          1           0
# 68         0         0           0           0          1           0
# 91         0         0           0           0          1           1
# 92         0         0           0           0          1           1
#
#     VISCODE_m03  VISCODE_m06  VISCODE_m102  VISCODE_m108   ...    APOE4_0.0  \
# 58            0            0             0             0   ...            0
# 59            0            0             0             0   ...            1
# 68            0            1             0             0   ...            1
# 91            0            0             0             0   ...            1
# 92            0            0             0             0   ...            1
#
#     APOE4_1.0  APOE4_2.0  FLDSTRENG_1.5 Tesla MRI  FLDSTRENG_3 Tesla MRI  \
# 58          1          0                        0                      1
# 59          0          0                        0                      0
# 68          0          0                        0                      0
# 91          0          0                        0                      1
# 92          0          0                        0                      1
#
#     FSVERSION_Cross-Sectional FreeSurfer (5.1)  \
# 58                                           1
# 59                                           0
# 68                                           0
# 91                                           1
# 92                                           1
#
#     FSVERSION_Cross-Sectional FreeSurfer (FreeSurfer Version 4.3)  DX_CN  \
# 58                                                  0                  1
# 59                                                  0                  1
# 68                                                  0                  1
# 91                                                  0                  1
# 92                                                  0                  1
#
#     DX_Dementia  DX_MCI
# 58            0       0
# 59            0       0
# 68            0       0
# 91            0       0
# 92            0       0
#
# [5 rows x 52 columns]

# %%
ADNI2_categorical.columns
# Out:
# Index(['DX_bl_AD', 'DX_bl_CN', 'DX_bl_EMCI', 'DX_bl_LMCI', 'DX_bl_SMC',
#        'VISCODE_bl', 'VISCODE_m03', 'VISCODE_m06', 'VISCODE_m102',
#        'VISCODE_m108', 'VISCODE_m114', 'VISCODE_m12', 'VISCODE_m120',
#        'VISCODE_m126', 'VISCODE_m18', 'VISCODE_m24', 'VISCODE_m30',
#        'VISCODE_m36', 'VISCODE_m42', 'VISCODE_m48', 'VISCODE_m54',
#        'VISCODE_m60', 'VISCODE_m66', 'VISCODE_m72', 'VISCODE_m78',
#        'VISCODE_m84', 'VISCODE_m90', 'VISCODE_m96', 'PTGENDER_Female',
#        'PTGENDER_Male', 'PTETHCAT_Hisp/Latino', 'PTETHCAT_Not Hisp/Latino',
#        'PTRACCAT_Am Indian/Alaskan', 'PTRACCAT_Asian', 'PTRACCAT_Black',
#        'PTRACCAT_Hawaiian/Other PI', 'PTRACCAT_More than one',
#        'PTRACCAT_White', 'PTMARRY_Divorced', 'PTMARRY_Married',
#        'PTMARRY_Never married', 'PTMARRY_Widowed', 'APOE4_0.0', 'APOE4_1.0',
#        'APOE4_2.0', 'FLDSTRENG_1.5 Tesla MRI', 'FLDSTRENG_3 Tesla MRI',
#        'FSVERSION_Cross-Sectional FreeSurfer (5.1)',
#        'FSVERSION_Cross-Sectional FreeSurfer (FreeSurfer Version 4.3)',
#        'DX_CN', 'DX_Dementia', 'DX_MCI'],
#       dtype='object')

# %%
''' Create ADNI2_missing for imputation '''
#ADNI2_remove_categorical = ADNI2[[column for column in ADNI2.columns if column not in categorical_predictors]]
ADNI2_remove_categorical = ADNI2[continuous_predictors]

''' Create the Dataframe for imputation '''
ADNI2_missing = pd.concat([ADNI2_remove_categorical, ADNI2_categorical], axis=1)

# %%
print(ADNI2_remove_categorical.shape)
print(ADNI2_categorical.shape)
# Out:
# (6937, 68)
# (6937, 52)

# %%
ADNI2_missing.head()
# Out:
#      AGE      FDG      AV45  CDRSB  ADAS11  ADAS13  MMSE  RAVLT_immediate  \
# 58  66.9  1.13549  1.326790    0.0    10.0    15.0  29.0             42.0
# 59  67.5      NaN  0.982566    0.0     2.0     3.0  30.0             38.0
# 68  67.5      NaN       NaN    0.0     3.0     4.0  29.0             54.0
# 91  67.5  1.25195  0.983143    0.0     3.0     5.0  30.0             42.0
# 92  68.5  1.50629  0.985156    0.0     4.0     7.0  30.0             61.0
#
#     RAVLT_learning  RAVLT_forgetting   ...    APOE4_0.0  APOE4_1.0  APOE4_2.0  \
# 58             5.0               2.0   ...            0          1          0
# 59             6.0               5.0   ...            1          0          0
# 68             6.0               2.0   ...            1          0          0
# 91             7.0               2.0   ...            1          0          0
# 92             6.0               3.0   ...            1          0          0
#
#     FLDSTRENG_1.5 Tesla MRI  FLDSTRENG_3 Tesla MRI  \
# 58                        0                      1
# 59                        0                      0
# 68                        0                      0
# 91                        0                      1
# 92                        0                      1
#
#     FSVERSION_Cross-Sectional FreeSurfer (5.1)  \
# 58                                           1
# 59                                           0
# 68                                           0
# 91                                           1
# 92                                           1
#
#     FSVERSION_Cross-Sectional FreeSurfer (FreeSurfer Version 4.3)  DX_CN  \
# 58                                                  0                  1
# 59                                                  0                  1
# 68                                                  0                  1
# 91                                                  0                  1
# 92                                                  0                  1
#
#     DX_Dementia  DX_MCI
# 58            0       0
# 59            0       0
# 68            0       0
# 91            0       0
# 92            0       0
#
# [5 rows x 120 columns]

# %%
print(ADNI2_missing.shape)
# Out:
# (6937, 120)

# %%
full_dataframe =  copy(ADNI2_missing)
missing_rows = []
for i in range(ADNI2_missing.shape[0]):
    if pd.isnull(ADNI2_missing.values[i]).any():
        missing_rows.append(i)
full_dataframe = full_dataframe.drop(full_dataframe.index[missing_rows], axis=0);

print('The origin number of data: {}'.format(len(ADNI2_missing)))
print('The number of data that contains missing entries: {}'.format(len(missing_rows)))
print('The dimension of full dataframe: {}'.format(full_dataframe.shape))
# Out:
# The origin number of data: 6937
# The number of data that contains missing entries: 6263
# The dimension of full dataframe: (674, 120)

# %%
''' To check that full_dataframe has no missing values '''
np.sum(np.sum(full_dataframe.isnull()))
# Out:
# 0

# %%
np.sum(np.sum(full_dataframe.isnull()))
# Out:
# 0

# %%
''' Model-Based Imputation - Linear Regression '''

from sklearn.metrics import mean_squared_error

lr = LinearRegression(fit_intercept = True)

for i in range(ADNI2_missing.shape[0]):
    if i % 1000 == 0:
        print(i)
    if ADNI2_missing.iloc[i, :].isnull().any():
        missing_columns = ADNI2_missing.columns[ADNI2_missing.iloc[i, :].isnull()]
        print(i, missing_columns)
        y_imp = full_dataframe[missing_columns]
        X_imp = full_dataframe.drop(missing_columns, 1)
        lr.fit(X_imp,y_imp)
        X_missing = ADNI2_missing.iloc[i, :].drop(missing_columns)
        y_hat = lr.predict(X_missing)
        ADNI2_missing.loc[ADNI2_missing.index[i], missing_columns] = y_hat[0]
# Out:
# 0
# 0 Index(['MOCA', 'EcogPtMem', 'EcogPtLang', 'EcogPtVisspat', 'EcogPtPlan',
#        'EcogPtOrgan', 'EcogPtDivatt', 'EcogPtTotal', 'Ventricles',
#        'WholeBrain', 'Entorhinal', 'Fusiform', 'MidTemp', 'Ventricles_bl',
#        'WholeBrain_bl', 'Entorhinal_bl', 'Fusiform_bl', 'MidTemp_bl',
#        'MOCA_bl', 'EcogPtMem_bl', 'EcogPtLang_bl', 'EcogPtVisspat_bl',
#        'EcogPtPlan_bl', 'EcogPtOrgan_bl', 'EcogPtDivatt_bl', 'EcogPtTotal_bl'],
#       dtype='object')
# 1 Index(['FDG', 'EcogSPMem', 'EcogSPLang', 'EcogSPVisspat', 'EcogSPPlan',
#        'EcogSPOrgan', 'EcogSPDivatt', 'EcogSPTotal', 'Ventricles',
#        'Hippocampus', 'WholeBrain', 'Entorhinal', 'Fusiform', 'MidTemp',
#        'ICV'],
#       dtype='object')
# 2 Index(['FDG', 'AV45', 'EcogSPOrgan', 'Ventricles', 'Hippocampus', 'WholeBrain',
#        'Entorhinal', 'Fusiform', 'MidTemp', 'ICV'],
#       dtype='object')
# 5 Index(['FDG', 'AV45', 'Ventricles', 'Hippocampus', 'WholeBrain', 'Entorhinal',
#        'Fusiform', 'MidTemp', 'ICV'],
#       dtype='object')
# 7 Index(['FDG'], dtype='object')
# 8 Index(['FDG', 'AV45', 'Ventricles', 'Hippocampus', 'WholeBrain', 'Entorhinal',
#        'Fusiform', 'MidTemp', 'ICV'],
#       dtype='object')
# 10 Index(['FDG', 'AV45', 'Ventricles', 'Hippocampus', 'WholeBrain', 'Entorhinal',
#        'Fusiform', 'MidTemp', 'ICV', 'Entorhinal_bl', 'Fusiform_bl',
#        'MidTemp_bl'],
#       dtype='object')
# 11 Index(['FDG', 'AV45', 'CDRSB', 'ADAS11', 'ADAS13', 'MMSE', 'RAVLT_immediate',
#        'RAVLT_learning', 'RAVLT_forgetting', 'RAVLT_perc_forgetting', 'FAQ',
#        'MOCA', 'EcogPtMem', 'EcogPtLang', 'EcogPtVisspat', 'EcogPtPlan',
#        'EcogPtOrgan', 'EcogPtDivatt', 'EcogPtTotal', 'EcogSPMem', 'EcogSPLang',
#        'EcogSPVisspat', 'EcogSPPlan', 'EcogSPOrgan', 'EcogSPDivatt',
#        'EcogSPTotal', 'Ventricles', 'Hippocampus', 'WholeBrain', 'Entorhinal',
#        'Fusiform', 'MidTemp', 'ICV', 'Entorhinal_bl', 'Fusiform_bl',
#        'MidTemp_bl'],
#       dtype='object')
# 12 Index(['Entorhinal', 'Fusiform', 'MidTemp', 'Entorhinal_bl', 'Fusiform_bl',
#        'MidTemp_bl'],
#       dtype='object')
# 13 Index(['FDG', 'AV45', 'Ventricles', 'Hippocampus', 'WholeBrain', 'Entorhinal',
#        'Fusiform', 'MidTemp', 'ICV', 'Entorhinal_bl', 'Fusiform_bl',
#        'MidTemp_bl'],
#       dtype='object')
# 14 Index(['FDG', 'Entorhinal_bl', 'Fusiform_bl', 'MidTemp_bl'], dtype='object')
# 15 Index(['FDG', 'AV45', 'Ventricles', 'Hippocampus', 'WholeBrain', 'Entorhinal',
#        'Fusiform', 'MidTemp', 'ICV', 'Entorhinal_bl', 'Fusiform_bl',
#        'MidTemp_bl'],
#       dtype='object')
# 16 Index(['FDG', 'AV45', 'Ventricles', 'Hippocampus', 'WholeBrain', 'Entorhinal',
#        'Fusiform', 'MidTemp', 'ICV', 'Entorhinal_bl', 'Fusiform_bl',
#        'MidTemp_bl'],
#       dtype='object')
# 17 Index(['FDG', 'AV45', 'CDRSB', 'ADAS11', 'ADAS13', 'MMSE', 'RAVLT_immediate',
#        'RAVLT_learning', 'RAVLT_forgetting', 'RAVLT_perc_forgetting', 'FAQ',
#        'MOCA', 'EcogPtMem', 'EcogPtLang', 'EcogPtVisspat', 'EcogPtPlan',
#        'EcogPtOrgan', 'EcogPtDivatt', 'EcogPtTotal', 'EcogSPMem', 'EcogSPLang',
#        'EcogSPVisspat', 'EcogSPPlan', 'EcogSPOrgan', 'EcogSPDivatt',
#        'EcogSPTotal', 'Ventricles', 'Hippocampus', 'WholeBrain', 'Entorhinal',
#        'Fusiform', 'MidTemp', 'ICV', 'Entorhinal_bl', 'Fusiform_bl',
#        'MidTemp_bl'],
#       dtype='object')
# 18 Index(['Entorhinal', 'Fusiform', 'MidTemp', 'Entorhinal_bl', 'Fusiform_bl',
#        'MidTemp_bl'],
#       dtype='object')
# 19 Index(['FDG', 'Ventricles', 'Hippocampus', 'WholeBrain', 'Entorhinal',
#        'Fusiform', 'MidTemp', 'ICV'],
#       dtype='object')
# 20 Index(['FDG', 'AV45', 'Ventricles', 'Hippocampus', 'WholeBrain', 'Entorhinal',
#        'Fusiform', 'MidTemp', 'ICV'],
#       dtype='object')
# 22 Index(['FDG', 'AV45', 'Ventricles', 'Hippocampus', 'WholeBrain', 'Entorhinal',
#        'Fusiform', 'MidTemp', 'ICV'],
#       dtype='object')
# 23 Index(['FDG', 'AV45', 'Ventricles', 'Hippocampus', 'WholeBrain', 'Entorhinal',
#        'Fusiform', 'MidTemp', 'ICV'],
#       dtype='object')
# 25 Index(['FDG', 'AV45', 'CDRSB', 'RAVLT_immediate', 'RAVLT_learning',
#        'RAVLT_forgetting', 'RAVLT_perc_forgetting', 'MOCA', 'EcogPtMem',
#        'EcogPtLang', 'EcogPtVisspat', 'EcogPtPlan', 'EcogPtOrgan',
#        'EcogPtDivatt', 'EcogPtTotal', 'EcogSPMem', 'EcogSPLang',
#        'EcogSPVisspat', 'EcogSPPlan', 'EcogSPOrgan', 'EcogSPDivatt',
#        'EcogSPTotal', 'Ventricles', 'Hippocampus', 'WholeBrain', 'Entorhinal',
#        'Fusiform', 'MidTemp', 'ICV'],
#       dtype='object')
# 26 Index(['FDG'], dtype='object')
# 27 Index(['FDG', 'AV45', 'Ventricles', 'Hippocampus', 'WholeBrain', 'Entorhinal',
#        'Fusiform', 'MidTemp', 'ICV'],
#       dtype='object')
# 28 Index(['FDG', 'AV45', 'CDRSB', 'ADAS11', 'ADAS13', 'MMSE', 'RAVLT_immediate',
#        'RAVLT_learning', 'RAVLT_forgetting', 'RAVLT_perc_forgetting', 'FAQ',
#        'MOCA', 'EcogPtMem', 'EcogPtLang', 'EcogPtVisspat', 'EcogPtPlan',
#        'EcogPtOrgan', 'EcogPtDivatt', 'EcogPtTotal', 'EcogSPMem', 'EcogSPLang',
#        'EcogSPVisspat', 'EcogSPPlan', 'EcogSPOrgan', 'EcogSPDivatt',
#        'EcogSPTotal', 'Ventricles', 'Hippocampus', 'WholeBrain', 'Entorhinal',
#        'Fusiform', 'MidTemp', 'ICV'],
#       dtype='object')
# 30 Index(['FDG', 'AV45', 'Ventricles', 'Hippocampus', 'WholeBrain', 'Entorhinal',
#        'Fusiform', 'MidTemp', 'ICV'],
#       dtype='object')
# 32 Index(['FDG'], dtype='object')
# 33 Index(['FDG', 'AV45', 'Ventricles', 'Hippocampus', 'WholeBrain', 'Entorhinal',
#        'Fusiform', 'MidTemp', 'ICV'],
#       dtype='object')
# 35 Index(['FDG', 'Ventricles', 'Hippocampus', 'WholeBrain', 'Entorhinal',
#        'Fusiform', 'MidTemp', 'ICV'],
#       dtype='object')
# 36 Index(['FDG', 'AV45', 'Ventricles', 'Hippocampus', 'WholeBrain', 'Entorhinal',
#        'Fusiform', 'MidTemp', 'ICV'],
#       dtype='object')
# 38 Index(['FDG', 'AV45', 'Ventricles', 'Hippocampus', 'WholeBrain', 'Entorhinal',
#        'Fusiform', 'MidTemp', 'ICV'],
#       dtype='object')
# 39 Index(['FDG'], dtype='object')
# 40 Index(['FDG', 'AV45', 'Ventricles', 'Hippocampus', 'WholeBrain', 'Entorhinal',
#        'Fusiform', 'MidTemp', 'ICV'],
#       dtype='object')
# 42 Index(['FDG', 'AV45', 'EcogSPMem', 'EcogSPLang', 'EcogSPVisspat', 'EcogSPPlan',
#        'EcogSPOrgan', 'EcogSPDivatt', 'EcogSPTotal', 'EcogSPMem_bl',
#        'EcogSPLang_bl', 'EcogSPVisspat_bl', 'EcogSPPlan_bl', 'EcogSPOrgan_bl',
#        'EcogSPDivatt_bl', 'EcogSPTotal_bl', 'FDG_bl', 'AV45_bl'],
#       dtype='object')
# 43 Index(['FDG'], dtype='object')
# 44 Index(['FDG', 'AV45', 'Ventricles', 'Hippocampus', 'WholeBrain', 'Entorhinal',
#        'Fusiform', 'MidTemp', 'ICV'],
#       dtype='object')
# 46 Index(['FDG', 'EcogSPOrgan', 'EcogSPOrgan_bl', 'EcogSPDivatt_bl'], dtype='object')
# 47 Index(['FDG', 'AV45', 'EcogSPOrgan', 'Ventricles', 'Hippocampus', 'WholeBrain',
#        'Entorhinal', 'Fusiform', 'MidTemp', 'ICV', 'EcogSPOrgan_bl',
#        'EcogSPDivatt_bl'],
#       dtype='object')
# 48 Index(['EcogSPOrgan', 'EcogSPDivatt', 'EcogSPOrgan_bl', 'EcogSPDivatt_bl'], dtype='object')
# 49 Index(['FDG', 'Ventricles', 'Hippocampus', 'WholeBrain', 'Entorhinal',
#        'Fusiform', 'MidTemp', 'ICV'],
#       dtype='object')
# 50 Index(['FDG', 'AV45', 'EcogSPOrgan', 'Ventricles', 'Hippocampus', 'WholeBrain',
#        'Entorhinal', 'Fusiform', 'MidTemp', 'ICV'],
#       dtype='object')
# 51 Index(['FDG', 'AV45', 'Ventricles', 'Hippocampus', 'WholeBrain', 'Entorhinal',
#        'Fusiform', 'MidTemp', 'ICV'],
#       dtype='object')
# 53 Index(['FDG', 'EcogSPPlan_bl'], dtype='object')
# 54 Index(['FDG', 'AV45', 'Ventricles', 'Hippocampus', 'WholeBrain', 'Entorhinal',
#        'Fusiform', 'MidTemp', 'ICV', 'EcogSPPlan_bl'],
#       dtype='object')
# 55 Index(['EcogSPPlan', 'EcogSPPlan_bl'], dtype='object')
# 56 Index(['FDG'], dtype='object')
# 57 Index(['FDG', 'AV45', 'Ventricles', 'Hippocampus', 'WholeBrain', 'Entorhinal',
#        'Fusiform', 'MidTemp', 'ICV'],
#       dtype='object')
# 59 Index(['FDG', 'AV45', 'Ventricles', 'Entorhinal', 'Fusiform', 'MidTemp',
#        'EcogPtOrgan_bl'],
#       dtype='object')
# 60 Index(['EcogPtOrgan', 'EcogPtOrgan_bl'], dtype='object')
# 61 Index(['FDG', 'AV45', 'Ventricles', 'Hippocampus', 'WholeBrain', 'Entorhinal',
#        'Fusiform', 'MidTemp', 'ICV', 'Entorhinal_bl', 'Fusiform_bl',
#        'MidTemp_bl'],
#       dtype='object')
# 62 Index(['Entorhinal', 'Fusiform', 'MidTemp', 'Entorhinal_bl', 'Fusiform_bl',
#        'MidTemp_bl'],
#       dtype='object')
# 64 Index(['FDG', 'AV45', 'Ventricles', 'Hippocampus', 'WholeBrain', 'Entorhinal',
#        'Fusiform', 'MidTemp', 'ICV'],
#       dtype='object')
# 66 Index(['FDG'], dtype='object')
# 67 Index(['FDG', 'AV45', 'Ventricles', 'Hippocampus', 'WholeBrain', 'Entorhinal',
#        'Fusiform', 'MidTemp', 'ICV'],
#       dtype='object')
# 69 Index(['FDG', 'Hippocampus_bl'], dtype='object')
# 70 Index(['FDG', 'AV45', 'Ventricles', 'Hippocampus', 'WholeBrain', 'Entorhinal',
#        'Fusiform', 'MidTemp', 'ICV', 'Hippocampus_bl'],
#       dtype='object')
# 71 Index(['FDG', 'AV45', 'CDRSB', 'ADAS11', 'ADAS13', 'MMSE', 'RAVLT_immediate',
#        'RAVLT_learning', 'RAVLT_forgetting', 'RAVLT_perc_forgetting', 'FAQ',
#        'MOCA', 'EcogPtMem', 'EcogPtLang', 'EcogPtVisspat', 'EcogPtPlan',
#        'EcogPtOrgan', 'EcogPtDivatt', 'EcogPtTotal', 'EcogSPMem', 'EcogSPLang',
#        'EcogSPVisspat', 'EcogSPPlan', 'EcogSPOrgan', 'EcogSPDivatt',
#        'EcogSPTotal', 'Ventricles', 'Hippocampus', 'WholeBrain', 'Entorhinal',
#        'Fusiform', 'MidTemp', 'ICV', 'Hippocampus_bl'],
#       dtype='object')
# 72 Index(['Hippocampus', 'Hippocampus_bl'], dtype='object')
# 73 Index(['FDG'], dtype='object')
# 74 Index(['FDG', 'AV45'], dtype='object')
# 76 Index(['Ventricles', 'WholeBrain', 'Entorhinal', 'Fusiform', 'MidTemp',
#        'Ventricles_bl', 'WholeBrain_bl', 'Entorhinal_bl', 'Fusiform_bl',
#        'MidTemp_bl'],
#       dtype='object')
# 78 Index(['FDG', 'AV45', 'Ventricles', 'Entorhinal', 'Fusiform', 'MidTemp',
#        'Entorhinal_bl', 'Fusiform_bl', 'MidTemp_bl'],
#       dtype='object')
# 79 Index(['FDG', 'AV45', 'Ventricles', 'Hippocampus', 'WholeBrain', 'Entorhinal',
#        'Fusiform', 'MidTemp', 'ICV', 'Entorhinal_bl', 'Fusiform_bl',
#        'MidTemp_bl'],
#       dtype='object')
# 80 Index(['FDG', 'AV45', 'CDRSB', 'ADAS11', 'ADAS13', 'MMSE', 'RAVLT_immediate',
#        'RAVLT_learning', 'RAVLT_forgetting', 'RAVLT_perc_forgetting', 'FAQ',
#        'MOCA', 'EcogPtMem', 'EcogPtLang', 'EcogPtVisspat', 'EcogPtPlan',
#        'EcogPtOrgan', 'EcogPtDivatt', 'EcogPtTotal', 'EcogSPMem', 'EcogSPLang',
#        'EcogSPVisspat', 'EcogSPPlan', 'EcogSPOrgan', 'EcogSPDivatt',
#        'EcogSPTotal', 'Entorhinal', 'Fusiform', 'MidTemp', 'Entorhinal_bl',
#        'Fusiform_bl', 'MidTemp_bl'],
#       dtype='object')
# 81 Index(['Entorhinal', 'Fusiform', 'MidTemp', 'Entorhinal_bl', 'Fusiform_bl',
#        'MidTemp_bl'],
#       dtype='object')
# 82 Index(['FDG', 'AV45'], dtype='object')
# 83 Index(['FDG', 'AV45', 'Ventricles', 'Hippocampus', 'WholeBrain', 'Entorhinal',
#        'Fusiform', 'MidTemp', 'ICV'],
#       dtype='object')
# 84 Index(['FDG', 'AV45', 'CDRSB', 'ADAS11', 'ADAS13', 'MMSE', 'RAVLT_immediate',
#        'RAVLT_learning', 'RAVLT_forgetting', 'RAVLT_perc_forgetting', 'FAQ',
#        'MOCA', 'EcogPtMem', 'EcogPtLang', 'EcogPtVisspat', 'EcogPtPlan',
#        'EcogPtOrgan', 'EcogPtDivatt', 'EcogPtTotal', 'EcogSPMem', 'EcogSPLang',
#        'EcogSPVisspat', 'EcogSPPlan', 'EcogSPOrgan', 'EcogSPDivatt',
#        'EcogSPTotal'],
#       dtype='object')
# 86 Index(['FDG', 'AV45', 'CDRSB', 'ADAS11', 'ADAS13', 'MMSE', 'RAVLT_immediate',
#        'RAVLT_learning', 'RAVLT_forgetting', 'RAVLT_perc_forgetting', 'FAQ',
#        'MOCA', 'EcogPtMem', 'EcogPtLang', 'EcogPtVisspat', 'EcogPtPlan',
#        'EcogPtOrgan', 'EcogPtDivatt', 'EcogPtTotal', 'EcogSPMem', 'EcogSPLang',
#        'EcogSPVisspat', 'EcogSPPlan', 'EcogSPOrgan', 'EcogSPDivatt',
#        'EcogSPTotal', 'Ventricles', 'Hippocampus', 'WholeBrain', 'Entorhinal',
#        'Fusiform', 'MidTemp', 'ICV'],
#       dtype='object')
# 87 Index(['FDG', 'AV45', 'Ventricles', 'Hippocampus', 'WholeBrain', 'Entorhinal',
#        'Fusiform', 'MidTemp', 'ICV'],
#       dtype='object')
# 88 Index(['FDG', 'AV45', 'CDRSB', 'ADAS11', 'ADAS13', 'MMSE', 'RAVLT_immediate',
#        'RAVLT_learning', 'RAVLT_forgetting', 'RAVLT_perc_forgetting', 'FAQ',
#        'MOCA', 'EcogPtMem', 'EcogPtLang', 'EcogPtVisspat', 'EcogPtPlan',
#        'EcogPtOrgan', 'EcogPtDivatt', 'EcogPtTotal', 'EcogSPMem', 'EcogSPLang',
#        'EcogSPVisspat', 'EcogSPPlan', 'EcogSPOrgan', 'EcogSPDivatt',
#        'EcogSPTotal'],
#       dtype='object')
# 90 Index(['FDG', 'EcogPtLang', 'EcogPtVisspat', 'EcogSPVisspat'], dtype='object')
# 91 Index(['FDG', 'AV45', 'Ventricles', 'Hippocampus', 'WholeBrain', 'Entorhinal',
#        'Fusiform', 'MidTemp', 'ICV'],
#       dtype='object')
# 92 Index(['FDG', 'AV45', 'CDRSB', 'ADAS11', 'ADAS13', 'MMSE', 'RAVLT_immediate',
#        'RAVLT_learning', 'RAVLT_forgetting', 'RAVLT_perc_forgetting', 'FAQ',
#        'MOCA', 'EcogPtMem', 'EcogPtLang', 'EcogPtVisspat', 'EcogPtPlan',
#        'EcogPtOrgan', 'EcogPtDivatt', 'EcogPtTotal', 'EcogSPMem', 'EcogSPLang',
#        'EcogSPVisspat', 'EcogSPPlan', 'EcogSPOrgan', 'EcogSPDivatt',
#        'EcogSPTotal'],
#       dtype='object')
# 94 Index(['FDG', 'AV45', 'Ventricles', 'Hippocampus', 'WholeBrain', 'Entorhinal',
#        'Fusiform', 'MidTemp', 'ICV', 'Ventricles_bl', 'WholeBrain_bl',
#        'Entorhinal_bl', 'Fusiform_bl', 'MidTemp_bl'],
#       dtype='object')
# 95 Index(['Ventricles', 'WholeBrain', 'Entorhinal', 'Fusiform', 'MidTemp',
#        'Ventricles_bl', 'WholeBrain_bl', 'Entorhinal_bl', 'Fusiform_bl',
#        'MidTemp_bl'],
#       dtype='object')
# 96 Index(['FDG', 'Ventricles', 'Hippocampus', 'WholeBrain', 'Entorhinal',
#        'Fusiform', 'MidTemp', 'ICV'],
#       dtype='object')
# 97 Index(['FDG', 'AV45', 'Ventricles', 'Entorhinal', 'Fusiform', 'MidTemp'], dtype='object')
# 98 Index(['FDG', 'AV45', 'CDRSB', 'ADAS11', 'ADAS13', 'MMSE', 'RAVLT_immediate',
#        'RAVLT_learning', 'RAVLT_forgetting', 'RAVLT_perc_forgetting', 'FAQ',
#        'MOCA', 'EcogPtMem', 'EcogPtLang', 'EcogPtVisspat', 'EcogPtPlan',
#        'EcogPtOrgan', 'EcogPtDivatt', 'EcogPtTotal', 'EcogSPMem', 'EcogSPLang',
#        'EcogSPVisspat', 'EcogSPPlan', 'EcogSPOrgan', 'EcogSPDivatt',
#        'EcogSPTotal'],
#       dtype='object')
# 100 Index(['FDG'], dtype='object')
# 101 Index(['FDG', 'AV45', 'Ventricles', 'Hippocampus', 'WholeBrain', 'Entorhinal',
#        'Fusiform', 'MidTemp', 'ICV'],
#       dtype='object')
# 103 Index(['FDG'], dtype='object')
# 104 Index(['FDG', 'AV45', 'Ventricles', 'Hippocampus', 'WholeBrain', 'Entorhinal',
#        'Fusiform', 'MidTemp', 'ICV'],
#       dtype='object')
# 106 Index(['FDG', 'AV45', 'EcogSPOrgan', 'EcogSPDivatt', 'Ventricles',
#        'Hippocampus', 'WholeBrain', 'Entorhinal', 'Fusiform', 'MidTemp',
#        'ICV'],
#       dtype='object')
# 108 Index(['FDG', 'Ventricles', 'Hippocampus', 'WholeBrain', 'Entorhinal',
#        'Fusiform', 'MidTemp', 'ICV'],
#       dtype='object')
# 109 Index(['FDG', 'AV45', 'Ventricles', 'Hippocampus', 'WholeBrain', 'Entorhinal',
#        'Fusiform', 'MidTemp', 'ICV'],
#       dtype='object')
# 111 Index(['FDG'], dtype='object')
# 112 Index(['FDG', 'AV45', 'Ventricles', 'Hippocampus', 'WholeBrain', 'Entorhinal',
#        'Fusiform', 'MidTemp', 'ICV'],
#       dtype='object')
# 113 Index(['FDG', 'AV45', 'CDRSB', 'ADAS11', 'ADAS13', 'MMSE', 'RAVLT_immediate',
#        'RAVLT_learning', 'RAVLT_forgetting', 'RAVLT_perc_forgetting', 'FAQ',
#        'MOCA', 'EcogPtMem', 'EcogPtLang', 'EcogPtVisspat', 'EcogPtPlan',
#        'EcogPtOrgan', 'EcogPtDivatt', 'EcogPtTotal', 'EcogSPMem', 'EcogSPLang',
#        'EcogSPVisspat', 'EcogSPPlan', 'EcogSPOrgan', 'EcogSPDivatt',
#        'EcogSPTotal'],
#       dtype='object')
# 115 Index(['FDG', 'AV45', 'RAVLT_immediate', 'RAVLT_learning', 'RAVLT_forgetting',
#        'RAVLT_perc_forgetting', 'Ventricles', 'Hippocampus', 'WholeBrain',
#        'Entorhinal', 'Fusiform', 'MidTemp', 'ICV', 'Entorhinal_bl',
#        'Fusiform_bl', 'MidTemp_bl'],
#       dtype='object')
# 116 Index(['Entorhinal', 'Fusiform', 'MidTemp', 'Entorhinal_bl', 'Fusiform_bl',
#        'MidTemp_bl'],
#       dtype='object')
# 117 Index(['FDG', 'AV45', 'Ventricles', 'Hippocampus', 'WholeBrain', 'Entorhinal',
#        'Fusiform', 'MidTemp', 'ICV'],
#       dtype='object')
# 118 Index(['FDG'], dtype='object')
# 119 Index(['FDG', 'AV45', 'CDRSB', 'ADAS11', 'ADAS13', 'MMSE', 'RAVLT_immediate',
#        'RAVLT_learning', 'RAVLT_forgetting', 'RAVLT_perc_forgetting', 'FAQ',
#        'MOCA', 'EcogPtMem', 'EcogPtLang', 'EcogPtVisspat', 'EcogPtPlan',
#        'EcogPtOrgan', 'EcogPtDivatt', 'EcogPtTotal', 'EcogSPMem', 'EcogSPLang',
#        'EcogSPVisspat', 'EcogSPPlan', 'EcogSPOrgan', 'EcogSPDivatt',
#        'EcogSPTotal'],
#       dtype='object')
# 121 Index(['FDG'], dtype='object')
# 122 Index(['FDG', 'AV45', 'Ventricles', 'Hippocampus', 'WholeBrain', 'Entorhinal',
#        'Fusiform', 'MidTemp', 'ICV'],
#       dtype='object')
# 124 Index(['FDG', 'AV45', 'Ventricles', 'Hippocampus', 'WholeBrain', 'Entorhinal',
#        'Fusiform', 'MidTemp', 'ICV', 'Entorhinal_bl', 'Fusiform_bl',
#        'MidTemp_bl'],
#       dtype='object')
# 125 Index(['Entorhinal', 'Fusiform', 'MidTemp', 'Entorhinal_bl', 'Fusiform_bl',
#        'MidTemp_bl'],
#       dtype='object')
# 126 Index(['FDG', 'AV45', 'Ventricles', 'Hippocampus', 'WholeBrain', 'Entorhinal',
#        'Fusiform', 'MidTemp', 'ICV'],
#       dtype='object')
# 127 Index(['FDG', 'AV45', 'CDRSB', 'ADAS11', 'ADAS13', 'MMSE', 'RAVLT_immediate',
#        'RAVLT_learning', 'RAVLT_forgetting', 'RAVLT_perc_forgetting', 'FAQ',
#        'MOCA', 'EcogPtMem', 'EcogPtLang', 'EcogPtVisspat', 'EcogPtPlan',
#        'EcogPtOrgan', 'EcogPtDivatt', 'EcogPtTotal', 'EcogSPMem', 'EcogSPLang',
#        'EcogSPVisspat', 'EcogSPPlan', 'EcogSPOrgan', 'EcogSPDivatt',
#        'EcogSPTotal'],
#       dtype='object')
# 129 Index(['FDG', 'AV45', 'Ventricles', 'Hippocampus', 'WholeBrain', 'Entorhinal',
#        'Fusiform', 'MidTemp', 'ICV', 'Ventricles_bl', 'WholeBrain_bl',
#        'Entorhinal_bl', 'Fusiform_bl', 'MidTemp_bl'],
#       dtype='object')
# 130 Index(['FDG', 'AV45', 'Ventricles', 'Hippocampus', 'WholeBrain', 'Entorhinal',
#        'Fusiform', 'MidTemp', 'ICV', 'Ventricles_bl', 'WholeBrain_bl',
#        'Entorhinal_bl', 'Fusiform_bl', 'MidTemp_bl'],
#       dtype='object')
# 131 Index(['Ventricles', 'WholeBrain', 'Entorhinal', 'Fusiform', 'MidTemp',
#        'Ventricles_bl', 'WholeBrain_bl', 'Entorhinal_bl', 'Fusiform_bl',
#        'MidTemp_bl'],
#       dtype='object')
# 132 Index(['FDG', 'AV45', 'Ventricles', 'Hippocampus', 'WholeBrain', 'Entorhinal',
#        'Fusiform', 'MidTemp', 'ICV', 'Hippocampus_bl'],
#       dtype='object')
# 133 Index(['Hippocampus', 'Hippocampus_bl'], dtype='object')
# 134 Index(['FDG', 'AV45', 'EcogSPPlan_bl'], dtype='object')
# 135 Index(['FDG', 'AV45', 'EcogSPPlan_bl'], dtype='object')
# 136 Index(['FDG', 'AV45', 'CDRSB', 'ADAS11', 'ADAS13', 'MMSE', 'RAVLT_immediate',
#        'RAVLT_learning', 'RAVLT_forgetting', 'RAVLT_perc_forgetting', 'FAQ',
#        'MOCA', 'EcogPtMem', 'EcogPtLang', 'EcogPtVisspat', 'EcogPtPlan',
#        'EcogPtOrgan', 'EcogPtDivatt', 'EcogPtTotal', 'EcogSPMem', 'EcogSPLang',
#        'EcogSPVisspat', 'EcogSPPlan', 'EcogSPOrgan', 'EcogSPDivatt',
#        'EcogSPTotal', 'EcogSPPlan_bl'],
#       dtype='object')
# 137 Index(['EcogSPPlan', 'EcogSPPlan_bl'], dtype='object')
# 138 Index(['FDG', 'AV45', 'FDG_bl', 'AV45_bl'], dtype='object')
# 139 Index(['FDG', 'AV45', 'EcogPtMem', 'EcogPtLang', 'EcogPtVisspat', 'EcogPtPlan',
#        'EcogPtOrgan', 'EcogPtDivatt', 'EcogPtTotal', 'Ventricles',
#        'Hippocampus', 'WholeBrain', 'Entorhinal', 'Fusiform', 'MidTemp', 'ICV',
#        'EcogPtOrgan_bl'],
#       dtype='object')
# 140 Index(['FDG', 'AV45', 'CDRSB', 'ADAS11', 'ADAS13', 'MMSE', 'RAVLT_immediate',
#        'RAVLT_learning', 'RAVLT_forgetting', 'RAVLT_perc_forgetting', 'FAQ',
#        'MOCA', 'EcogPtMem', 'EcogPtLang', 'EcogPtVisspat', 'EcogPtPlan',
#        'EcogPtOrgan', 'EcogPtDivatt', 'EcogPtTotal', 'EcogSPMem', 'EcogSPLang',
#        'EcogSPVisspat', 'EcogSPPlan', 'EcogSPOrgan', 'EcogSPDivatt',
#        'EcogSPTotal', 'Entorhinal', 'Fusiform', 'MidTemp', 'EcogPtOrgan_bl'],
#       dtype='object')
# 141 Index(['EcogPtOrgan', 'EcogPtOrgan_bl'], dtype='object')
# 142 Index(['FDG', 'AV45', 'ADAS11', 'ADAS13', 'MMSE', 'RAVLT_immediate',
#        'RAVLT_learning', 'RAVLT_forgetting', 'RAVLT_perc_forgetting', 'MOCA',
#        'Ventricles', 'Hippocampus', 'WholeBrain', 'Entorhinal', 'Fusiform',
#        'MidTemp', 'ICV'],
#       dtype='object')
# 144 Index(['FDG', 'Entorhinal', 'Fusiform', 'MidTemp', 'Hippocampus_bl'], dtype='object')
# 145 Index(['FDG', 'AV45', 'Ventricles', 'Hippocampus', 'WholeBrain', 'Entorhinal',
#        'Fusiform', 'MidTemp', 'ICV', 'Hippocampus_bl'],
#       dtype='object')
# 146 Index(['FDG', 'AV45', 'CDRSB', 'ADAS11', 'ADAS13', 'MMSE', 'RAVLT_immediate',
#        'RAVLT_learning', 'RAVLT_forgetting', 'RAVLT_perc_forgetting', 'FAQ',
#        'MOCA', 'EcogPtMem', 'EcogPtLang', 'EcogPtVisspat', 'EcogPtPlan',
#        'EcogPtOrgan', 'EcogPtDivatt', 'EcogPtTotal', 'EcogSPMem', 'EcogSPLang',
#        'EcogSPVisspat', 'EcogSPPlan', 'EcogSPOrgan', 'EcogSPDivatt',
#        'EcogSPTotal', 'Entorhinal', 'Fusiform', 'MidTemp', 'Hippocampus_bl'],
#       dtype='object')
# 147 Index(['Hippocampus', 'Hippocampus_bl'], dtype='object')
# 148 Index(['FDG', 'AV45', 'CDRSB', 'ADAS11', 'ADAS13', 'RAVLT_immediate',
#        'RAVLT_learning', 'RAVLT_forgetting', 'RAVLT_perc_forgetting', 'FAQ',
#        'MOCA', 'EcogSPMem', 'EcogSPLang', 'EcogSPVisspat', 'EcogSPPlan',
#        'EcogSPOrgan', 'EcogSPDivatt', 'EcogSPTotal', 'Ventricles',
#        'Hippocampus', 'WholeBrain', 'Entorhinal', 'Fusiform', 'MidTemp', 'ICV',
#        'Hippocampus_bl', 'EcogSPPlan_bl', 'EcogSPOrgan_bl', 'EcogSPDivatt_bl'],
#       dtype='object')
# 149 Index(['FDG', 'FAQ', 'EcogSPMem', 'EcogSPLang', 'EcogSPVisspat', 'EcogSPPlan',
#        'EcogSPOrgan', 'EcogSPDivatt', 'EcogSPTotal', 'Ventricles',
#        'WholeBrain', 'Entorhinal', 'Fusiform', 'MidTemp', 'Hippocampus_bl',
#        'EcogSPPlan_bl', 'EcogSPOrgan_bl', 'EcogSPDivatt_bl'],
#       dtype='object')
# 150 Index(['FDG', 'AV45', 'Ventricles', 'Hippocampus', 'WholeBrain', 'Entorhinal',
#        'Fusiform', 'MidTemp', 'ICV', 'Hippocampus_bl', 'EcogSPPlan_bl',
#        'EcogSPOrgan_bl', 'EcogSPDivatt_bl'],
#       dtype='object')
# 151 Index(['FDG', 'AV45', 'CDRSB', 'ADAS11', 'ADAS13', 'MMSE', 'RAVLT_immediate',
#        'RAVLT_learning', 'RAVLT_forgetting', 'RAVLT_perc_forgetting', 'FAQ',
#        'MOCA', 'EcogPtMem', 'EcogPtLang', 'EcogPtVisspat', 'EcogPtPlan',
#        'EcogPtOrgan', 'EcogPtDivatt', 'EcogPtTotal', 'EcogSPMem', 'EcogSPLang',
#        'EcogSPVisspat', 'EcogSPPlan', 'EcogSPOrgan', 'EcogSPDivatt',
#        'EcogSPTotal', 'Hippocampus_bl', 'EcogSPPlan_bl', 'EcogSPOrgan_bl',
#        'EcogSPDivatt_bl'],
#       dtype='object')
# 152 Index(['EcogSPPlan', 'EcogSPOrgan', 'EcogSPDivatt', 'Hippocampus',
#        'Hippocampus_bl', 'EcogSPPlan_bl', 'EcogSPOrgan_bl', 'EcogSPDivatt_bl'],
#       dtype='object')
# 153 Index(['FDG', 'Ventricles', 'Hippocampus', 'WholeBrain', 'Entorhinal',
#        'Fusiform', 'MidTemp', 'ICV', 'Entorhinal_bl', 'Fusiform_bl',
#        'MidTemp_bl'],
#       dtype='object')
# 154 Index(['FDG', 'AV45', 'Ventricles', 'Hippocampus', 'WholeBrain', 'Entorhinal',
#        'Fusiform', 'MidTemp', 'ICV', 'Entorhinal_bl', 'Fusiform_bl',
#        'MidTemp_bl'],
#       dtype='object')
# 155 Index(['FDG', 'AV45', 'CDRSB', 'ADAS11', 'ADAS13', 'MMSE', 'RAVLT_immediate',
#        'RAVLT_learning', 'RAVLT_forgetting', 'RAVLT_perc_forgetting', 'FAQ',
#        'MOCA', 'EcogPtMem', 'EcogPtLang', 'EcogPtVisspat', 'EcogPtPlan',
#        'EcogPtOrgan', 'EcogPtDivatt', 'EcogPtTotal', 'EcogSPMem', 'EcogSPLang',
#        'EcogSPVisspat', 'EcogSPPlan', 'EcogSPOrgan', 'EcogSPDivatt',
#        'EcogSPTotal', 'Entorhinal_bl', 'Fusiform_bl', 'MidTemp_bl'],
#       dtype='object')
# 156 Index(['Entorhinal', 'Fusiform', 'MidTemp', 'Entorhinal_bl', 'Fusiform_bl',
#        'MidTemp_bl'],
#       dtype='object')
# 157 Index(['FDG', 'AV45', 'Ventricles', 'Hippocampus', 'WholeBrain', 'Entorhinal',
#        'Fusiform', 'MidTemp', 'ICV'],
#       dtype='object')
# 158 Index(['FDG', 'Ventricles', 'Hippocampus', 'WholeBrain', 'Entorhinal',
#        'Fusiform', 'MidTemp', 'ICV'],
#       dtype='object')
# 159 Index(['FDG', 'AV45', 'Ventricles', 'Hippocampus', 'WholeBrain', 'Entorhinal',
#        'Fusiform', 'MidTemp', 'ICV'],
#       dtype='object')
# 160 Index(['FDG', 'AV45', 'CDRSB', 'ADAS11', 'ADAS13', 'MMSE', 'RAVLT_immediate',
#        'RAVLT_learning', 'RAVLT_forgetting', 'RAVLT_perc_forgetting', 'FAQ',
#        'MOCA', 'EcogPtMem', 'EcogPtLang', 'EcogPtVisspat', 'EcogPtPlan',
#        'EcogPtOrgan', 'EcogPtDivatt', 'EcogPtTotal', 'EcogSPMem', 'EcogSPLang',
#        'EcogSPVisspat', 'EcogSPPlan', 'EcogSPOrgan', 'EcogSPDivatt',
#        'EcogSPTotal'],
#       dtype='object')
# 162 Index(['FDG'], dtype='object')
# 163 Index(['FDG', 'AV45', 'Ventricles', 'Hippocampus', 'WholeBrain', 'Entorhinal',
#        'Fusiform', 'MidTemp', 'ICV'],
#       dtype='object')
# 164 Index(['FDG', 'AV45', 'CDRSB', 'ADAS11', 'ADAS13', 'MMSE', 'RAVLT_immediate',
#        'RAVLT_learning', 'RAVLT_forgetting', 'RAVLT_perc_forgetting', 'FAQ',
#        'MOCA', 'EcogPtMem', 'EcogPtLang', 'EcogPtVisspat', 'EcogPtPlan',
#        'EcogPtOrgan', 'EcogPtDivatt', 'EcogPtTotal', 'EcogSPMem', 'EcogSPLang',
#        'EcogSPVisspat', 'EcogSPPlan', 'EcogSPOrgan', 'EcogSPDivatt',
#        'EcogSPTotal'],
#       dtype='object')
# 166 Index(['FDG', 'EcogSPOrgan', 'Ventricles', 'Entorhinal', 'Fusiform', 'MidTemp',
#        'Ventricles_bl', 'Entorhinal_bl', 'Fusiform_bl', 'MidTemp_bl'],
#       dtype='object')
# 167 Index(['FDG', 'AV45', 'Ventricles', 'Hippocampus', 'WholeBrain', 'Entorhinal',
#        'Fusiform', 'MidTemp', 'ICV', 'Ventricles_bl', 'Entorhinal_bl',
#        'Fusiform_bl', 'MidTemp_bl'],
#       dtype='object')
# 168 Index(['FDG', 'AV45', 'CDRSB', 'ADAS11', 'ADAS13', 'MMSE', 'RAVLT_immediate',
#        'RAVLT_learning', 'RAVLT_forgetting', 'RAVLT_perc_forgetting', 'FAQ',
#        'MOCA', 'EcogPtMem', 'EcogPtLang', 'EcogPtVisspat', 'EcogPtPlan',
#        'EcogPtOrgan', 'EcogPtDivatt', 'EcogPtTotal', 'EcogSPMem', 'EcogSPLang',
#        'EcogSPVisspat', 'EcogSPPlan', 'EcogSPOrgan', 'EcogSPDivatt',
#        'EcogSPTotal', 'Ventricles', 'WholeBrain', 'Entorhinal', 'Fusiform',
#        'MidTemp', 'Ventricles_bl', 'Entorhinal_bl', 'Fusiform_bl',
#        'MidTemp_bl'],
#       dtype='object')
# 169 Index(['Ventricles', 'Entorhinal', 'Fusiform', 'MidTemp', 'Ventricles_bl',
#        'Entorhinal_bl', 'Fusiform_bl', 'MidTemp_bl'],
#       dtype='object')
# 170 Index(['FDG', 'AV45', 'EcogSPOrgan', 'Ventricles', 'Hippocampus', 'WholeBrain',
#        'Entorhinal', 'Fusiform', 'MidTemp', 'ICV', 'Ventricles_bl',
#        'WholeBrain_bl', 'Entorhinal_bl', 'Fusiform_bl', 'MidTemp_bl',
#        'MOCA_bl'],
#       dtype='object')
# 171 Index(['FDG', 'AV45', 'Ventricles', 'Hippocampus', 'WholeBrain', 'Entorhinal',
#        'Fusiform', 'MidTemp', 'ICV', 'Ventricles_bl', 'WholeBrain_bl',
#        'Entorhinal_bl', 'Fusiform_bl', 'MidTemp_bl', 'MOCA_bl'],
#       dtype='object')
# 172 Index(['FDG', 'AV45', 'CDRSB', 'ADAS11', 'ADAS13', 'MMSE', 'RAVLT_immediate',
#        'RAVLT_learning', 'RAVLT_forgetting', 'RAVLT_perc_forgetting', 'FAQ',
#        'MOCA', 'EcogPtMem', 'EcogPtLang', 'EcogPtVisspat', 'EcogPtPlan',
#        'EcogPtOrgan', 'EcogPtDivatt', 'EcogPtTotal', 'EcogSPMem', 'EcogSPLang',
#        'EcogSPVisspat', 'EcogSPPlan', 'EcogSPOrgan', 'EcogSPDivatt',
#        'EcogSPTotal', 'Ventricles_bl', 'WholeBrain_bl', 'Entorhinal_bl',
#        'Fusiform_bl', 'MidTemp_bl', 'MOCA_bl'],
#       dtype='object')
# 173 Index(['MOCA', 'Ventricles', 'WholeBrain', 'Entorhinal', 'Fusiform', 'MidTemp',
#        'Ventricles_bl', 'WholeBrain_bl', 'Entorhinal_bl', 'Fusiform_bl',
#        'MidTemp_bl', 'MOCA_bl'],
#       dtype='object')
# 174 Index(['FDG', 'Ventricles', 'Hippocampus', 'WholeBrain', 'Entorhinal',
#        'Fusiform', 'MidTemp', 'ICV'],
#       dtype='object')
# 175 Index(['FDG', 'AV45', 'Ventricles', 'Hippocampus', 'WholeBrain', 'Entorhinal',
#        'Fusiform', 'MidTemp', 'ICV'],
#       dtype='object')
# 177 Index(['FDG', 'AV45', 'Ventricles', 'WholeBrain', 'Entorhinal', 'Fusiform',
#        'MidTemp', 'Ventricles_bl', 'WholeBrain_bl', 'Entorhinal_bl',
#        'Fusiform_bl', 'MidTemp_bl'],
#       dtype='object')
# 178 Index(['FDG', 'AV45', 'Ventricles', 'Hippocampus', 'WholeBrain', 'Entorhinal',
#        'Fusiform', 'MidTemp', 'ICV', 'Ventricles_bl', 'WholeBrain_bl',
#        'Entorhinal_bl', 'Fusiform_bl', 'MidTemp_bl'],
#       dtype='object')
# 179 Index(['FDG', 'AV45', 'CDRSB', 'ADAS11', 'ADAS13', 'MMSE', 'RAVLT_immediate',
#        'RAVLT_learning', 'RAVLT_forgetting', 'RAVLT_perc_forgetting', 'FAQ',
#        'MOCA', 'EcogPtMem', 'EcogPtLang', 'EcogPtVisspat', 'EcogPtPlan',
#        'EcogPtOrgan', 'EcogPtDivatt', 'EcogPtTotal', 'EcogSPMem', 'EcogSPLang',
#        'EcogSPVisspat', 'EcogSPPlan', 'EcogSPOrgan', 'EcogSPDivatt',
#        'EcogSPTotal', 'Entorhinal', 'Fusiform', 'MidTemp', 'Ventricles_bl',
#        'WholeBrain_bl', 'Entorhinal_bl', 'Fusiform_bl', 'MidTemp_bl'],
#       dtype='object')
# 180 Index(['Ventricles', 'WholeBrain', 'Entorhinal', 'Fusiform', 'MidTemp',
#        'Ventricles_bl', 'WholeBrain_bl', 'Entorhinal_bl', 'Fusiform_bl',
#        'MidTemp_bl'],
#       dtype='object')
# 181 Index(['FDG', 'Ventricles', 'Hippocampus', 'WholeBrain', 'Entorhinal',
#        'Fusiform', 'MidTemp', 'ICV'],
#       dtype='object')
# 182 Index(['FDG', 'AV45', 'Ventricles', 'Hippocampus', 'WholeBrain', 'Entorhinal',
#        'Fusiform', 'MidTemp', 'ICV'],
#       dtype='object')
# 183 Index(['FDG', 'AV45', 'CDRSB', 'ADAS11', 'ADAS13', 'MMSE', 'RAVLT_immediate',
#        'RAVLT_learning', 'RAVLT_forgetting', 'RAVLT_perc_forgetting', 'FAQ',
#        'MOCA', 'EcogPtMem', 'EcogPtLang', 'EcogPtVisspat', 'EcogPtPlan',
#        'EcogPtOrgan', 'EcogPtDivatt', 'EcogPtTotal', 'EcogSPMem', 'EcogSPLang',
#        'EcogSPVisspat', 'EcogSPPlan', 'EcogSPOrgan', 'EcogSPDivatt',
#        'EcogSPTotal'],
#       dtype='object')
# 185 Index(['FDG', 'AV45', 'CDRSB', 'ADAS11', 'ADAS13', 'MMSE', 'RAVLT_immediate',
#        'RAVLT_learning', 'RAVLT_forgetting', 'RAVLT_perc_forgetting', 'FAQ',
#        'MOCA', 'EcogPtMem', 'EcogPtLang', 'EcogPtVisspat', 'EcogPtPlan',
#        'EcogPtOrgan', 'EcogPtDivatt', 'EcogPtTotal', 'EcogSPMem', 'EcogSPLang',
#        'EcogSPVisspat', 'EcogSPPlan', 'EcogSPOrgan', 'EcogSPDivatt',
#        'EcogSPTotal', 'Ventricles', 'Hippocampus', 'WholeBrain', 'Entorhinal',
#        'Fusiform', 'MidTemp', 'ICV', 'Ventricles_bl', 'WholeBrain_bl',
#        'Entorhinal_bl', 'Fusiform_bl', 'MidTemp_bl'],
#       dtype='object')
# 186 Index(['FDG', 'AV45', 'Ventricles', 'Hippocampus', 'WholeBrain', 'Entorhinal',
#        'Fusiform', 'MidTemp', 'ICV', 'Ventricles_bl', 'WholeBrain_bl',
#        'Entorhinal_bl', 'Fusiform_bl', 'MidTemp_bl'],
#       dtype='object')
# 187 Index(['FDG', 'AV45', 'CDRSB', 'ADAS11', 'ADAS13', 'MMSE', 'RAVLT_immediate',
#        'RAVLT_learning', 'RAVLT_forgetting', 'RAVLT_perc_forgetting', 'FAQ',
#        'MOCA', 'EcogPtMem', 'EcogPtLang', 'EcogPtVisspat', 'EcogPtPlan',
#        'EcogPtOrgan', 'EcogPtDivatt', 'EcogPtTotal', 'EcogSPMem', 'EcogSPLang',
#        'EcogSPVisspat', 'EcogSPPlan', 'EcogSPOrgan', 'EcogSPDivatt',
#        'EcogSPTotal', 'Ventricles_bl', 'WholeBrain_bl', 'Entorhinal_bl',
#        'Fusiform_bl', 'MidTemp_bl'],
#       dtype='object')
# 188 Index(['Ventricles', 'WholeBrain', 'Entorhinal', 'Fusiform', 'MidTemp',
#        'Ventricles_bl', 'WholeBrain_bl', 'Entorhinal_bl', 'Fusiform_bl',
#        'MidTemp_bl'],
#       dtype='object')
# 189 Index(['FDG'], dtype='object')
# 190 Index(['FDG', 'AV45', 'Ventricles', 'Hippocampus', 'WholeBrain', 'Entorhinal',
#        'Fusiform', 'MidTemp', 'ICV'],
#       dtype='object')
# 191 Index(['FDG', 'AV45', 'CDRSB', 'ADAS11', 'ADAS13', 'MMSE', 'RAVLT_immediate',
#        'RAVLT_learning', 'RAVLT_forgetting', 'RAVLT_perc_forgetting', 'FAQ',
#        'MOCA', 'EcogPtMem', 'EcogPtLang', 'EcogPtVisspat', 'EcogPtPlan',
#        'EcogPtOrgan', 'EcogPtDivatt', 'EcogPtTotal', 'EcogSPMem', 'EcogSPLang',
#        'EcogSPVisspat', 'EcogSPPlan', 'EcogSPOrgan', 'EcogSPDivatt',
#        'EcogSPTotal', 'Entorhinal', 'Fusiform', 'MidTemp'],
#       dtype='object')
# 193 Index(['FDG', 'AV45', 'EcogSPPlan', 'EcogSPOrgan', 'Ventricles', 'Hippocampus',
#        'WholeBrain', 'Entorhinal', 'Fusiform', 'MidTemp', 'ICV'],
#       dtype='object')
# 195 Index(['FDG', 'Ventricles', 'Hippocampus', 'WholeBrain', 'Entorhinal',
#        'Fusiform', 'MidTemp', 'ICV', 'EcogSPOrgan_bl'],
#       dtype='object')
# 196 Index(['FDG', 'AV45', 'EcogSPOrgan_bl'], dtype='object')
# 197 Index(['FDG', 'AV45', 'CDRSB', 'ADAS11', 'ADAS13', 'MMSE', 'RAVLT_immediate',
#        'RAVLT_learning', 'RAVLT_forgetting', 'RAVLT_perc_forgetting', 'FAQ',
#        'MOCA', 'EcogPtMem', 'EcogPtLang', 'EcogPtVisspat', 'EcogPtPlan',
#        'EcogPtOrgan', 'EcogPtDivatt', 'EcogPtTotal', 'EcogSPMem', 'EcogSPLang',
#        'EcogSPVisspat', 'EcogSPPlan', 'EcogSPOrgan', 'EcogSPDivatt',
#        'EcogSPTotal', 'EcogSPOrgan_bl'],
#       dtype='object')
# 198 Index(['EcogSPOrgan', 'EcogSPOrgan_bl'], dtype='object')
# 199 Index(['FDG', 'AV45'], dtype='object')
# 200 Index(['FDG', 'AV45', 'Ventricles', 'Hippocampus', 'WholeBrain', 'Entorhinal',
#        'Fusiform', 'MidTemp', 'ICV'],
#       dtype='object')
# 201 Index(['FDG', 'AV45', 'CDRSB', 'ADAS11', 'ADAS13', 'MMSE', 'RAVLT_immediate',
#        'RAVLT_learning', 'RAVLT_forgetting', 'RAVLT_perc_forgetting', 'FAQ',
#        'MOCA', 'EcogPtMem', 'EcogPtLang', 'EcogPtVisspat', 'EcogPtPlan',
#        'EcogPtOrgan', 'EcogPtDivatt', 'EcogPtTotal', 'EcogSPMem', 'EcogSPLang',
#        'EcogSPVisspat', 'EcogSPPlan', 'EcogSPOrgan', 'EcogSPDivatt',
#        'EcogSPTotal'],
#       dtype='object')
# 203 Index(['FDG', 'Ventricles'], dtype='object')
# 204 Index(['FDG', 'AV45', 'Ventricles', 'Hippocampus', 'WholeBrain', 'Entorhinal',
#        'Fusiform', 'MidTemp', 'ICV'],
#       dtype='object')
# 205 Index(['FDG', 'AV45', 'CDRSB', 'ADAS11', 'ADAS13', 'MMSE', 'RAVLT_immediate',
#        'RAVLT_learning', 'RAVLT_forgetting', 'RAVLT_perc_forgetting', 'FAQ',
#        'MOCA', 'EcogPtMem', 'EcogPtLang', 'EcogPtVisspat', 'EcogPtPlan',
#        'EcogPtOrgan', 'EcogPtDivatt', 'EcogPtTotal', 'EcogSPMem', 'EcogSPLang',
#        'EcogSPVisspat', 'EcogSPPlan', 'EcogSPOrgan', 'EcogSPDivatt',
#        'EcogSPTotal', 'Hippocampus'],
#       dtype='object')
# 207 Index(['FDG', 'Ventricles', 'Hippocampus', 'WholeBrain', 'Entorhinal',
#        'Fusiform', 'MidTemp', 'ICV'],
#       dtype='object')
# 208 Index(['FDG', 'AV45', 'Ventricles', 'Hippocampus', 'WholeBrain', 'Entorhinal',
#        'Fusiform', 'MidTemp', 'ICV'],
#       dtype='object')
# 209 Index(['FDG', 'AV45', 'CDRSB', 'ADAS11', 'ADAS13', 'MMSE', 'RAVLT_immediate',
#        'RAVLT_learning', 'RAVLT_forgetting', 'RAVLT_perc_forgetting', 'FAQ',
#        'MOCA', 'EcogPtMem', 'EcogPtLang', 'EcogPtVisspat', 'EcogPtPlan',
#        'EcogPtOrgan', 'EcogPtDivatt', 'EcogPtTotal', 'EcogSPMem', 'EcogSPLang',
#        'EcogSPVisspat', 'EcogSPPlan', 'EcogSPOrgan', 'EcogSPDivatt',
#        'EcogSPTotal'],
#       dtype='object')
# 211 Index(['FDG', 'Ventricles', 'Hippocampus', 'WholeBrain', 'Entorhinal',
#        'Fusiform', 'MidTemp', 'ICV', 'MOCA_bl'],
#       dtype='object')
# 212 Index(['FDG', 'AV45', 'Ventricles', 'Hippocampus', 'WholeBrain', 'Entorhinal',
#        'Fusiform', 'MidTemp', 'ICV', 'MOCA_bl'],
#       dtype='object')
# 213 Index(['MOCA', 'MOCA_bl'], dtype='object')
# 214 Index(['FDG', 'AV45', 'Ventricles', 'Hippocampus', 'WholeBrain', 'Entorhinal',
#        'Fusiform', 'MidTemp', 'ICV'],
#       dtype='object')
# 215 Index(['FDG', 'AV45', 'ADAS13', 'Ventricles', 'Hippocampus', 'WholeBrain',
#        'Entorhinal', 'Fusiform', 'MidTemp', 'ICV'],
#       dtype='object')
# 216 Index(['FDG', 'AV45', 'CDRSB', 'ADAS11', 'ADAS13', 'MMSE', 'RAVLT_immediate',
#        'RAVLT_learning', 'RAVLT_forgetting', 'RAVLT_perc_forgetting', 'FAQ',
#        'MOCA', 'EcogPtMem', 'EcogPtLang', 'EcogPtVisspat', 'EcogPtPlan',
#        'EcogPtOrgan', 'EcogPtDivatt', 'EcogPtTotal', 'EcogSPMem', 'EcogSPLang',
#        'EcogSPVisspat', 'EcogSPPlan', 'EcogSPOrgan', 'EcogSPDivatt',
#        'EcogSPTotal'],
#       dtype='object')
# 218 Index(['FDG', 'Ventricles', 'WholeBrain', 'Entorhinal', 'Fusiform', 'MidTemp'], dtype='object')
# 219 Index(['FDG', 'AV45', 'Ventricles', 'Hippocampus', 'WholeBrain', 'Entorhinal',
#        'Fusiform', 'MidTemp', 'ICV'],
#       dtype='object')
# 220 Index(['FDG', 'AV45', 'CDRSB', 'ADAS11', 'ADAS13', 'MMSE', 'RAVLT_immediate',
#        'RAVLT_learning', 'RAVLT_forgetting', 'RAVLT_perc_forgetting', 'FAQ',
#        'MOCA', 'EcogPtMem', 'EcogPtLang', 'EcogPtVisspat', 'EcogPtPlan',
#        'EcogPtOrgan', 'EcogPtDivatt', 'EcogPtTotal', 'EcogSPMem', 'EcogSPLang',
#        'EcogSPVisspat', 'EcogSPPlan', 'EcogSPOrgan', 'EcogSPDivatt',
#        'EcogSPTotal', 'Ventricles', 'WholeBrain', 'Entorhinal', 'Fusiform',
#        'MidTemp'],
#       dtype='object')
# 222 Index(['FDG'], dtype='object')
# 223 Index(['FDG', 'AV45', 'Ventricles', 'Hippocampus', 'WholeBrain', 'Entorhinal',
#        'Fusiform', 'MidTemp', 'ICV'],
#       dtype='object')
# 224 Index(['FDG', 'AV45', 'CDRSB', 'ADAS11', 'ADAS13', 'MMSE', 'RAVLT_immediate',
#        'RAVLT_learning', 'RAVLT_forgetting', 'RAVLT_perc_forgetting', 'FAQ',
#        'MOCA', 'EcogPtMem', 'EcogPtLang', 'EcogPtVisspat', 'EcogPtPlan',
#        'EcogPtOrgan', 'EcogPtDivatt', 'EcogPtTotal', 'EcogSPMem', 'EcogSPLang',
#        'EcogSPVisspat', 'EcogSPPlan', 'EcogSPOrgan', 'EcogSPDivatt',
#        'EcogSPTotal'],
#       dtype='object')
# 226 Index(['FDG', 'FAQ', 'EcogSPOrgan'], dtype='object')
# 227 Index(['FDG', 'AV45', 'Ventricles', 'Hippocampus', 'WholeBrain', 'Entorhinal',
#        'Fusiform', 'MidTemp', 'ICV'],
#       dtype='object')
# 228 Index(['FDG', 'AV45', 'CDRSB', 'ADAS11', 'ADAS13', 'MMSE', 'RAVLT_immediate',
#        'RAVLT_learning', 'RAVLT_forgetting', 'RAVLT_perc_forgetting', 'FAQ',
#        'MOCA', 'EcogPtMem', 'EcogPtLang', 'EcogPtVisspat', 'EcogPtPlan',
#        'EcogPtOrgan', 'EcogPtDivatt', 'EcogPtTotal', 'EcogSPMem', 'EcogSPLang',
#        'EcogSPVisspat', 'EcogSPPlan', 'EcogSPOrgan', 'EcogSPDivatt',
#        'EcogSPTotal'],
#       dtype='object')
# 230 Index(['FDG', 'AV45', 'CDRSB', 'ADAS11', 'ADAS13', 'MMSE', 'RAVLT_immediate',
#        'RAVLT_learning', 'RAVLT_forgetting', 'RAVLT_perc_forgetting', 'FAQ',
#        'MOCA', 'EcogPtMem', 'EcogPtLang', 'EcogPtVisspat', 'EcogPtPlan',
#        'EcogPtOrgan', 'EcogPtDivatt', 'EcogPtTotal', 'EcogSPMem', 'EcogSPLang',
#        'EcogSPVisspat', 'EcogSPPlan', 'EcogSPOrgan', 'EcogSPDivatt',
#        'EcogSPTotal', 'Ventricles', 'Hippocampus', 'WholeBrain', 'Entorhinal',
#        'Fusiform', 'MidTemp', 'ICV'],
#       dtype='object')
# 231 Index(['FDG', 'AV45', 'CDRSB', 'ADAS11', 'ADAS13', 'MMSE', 'RAVLT_immediate',
#        'RAVLT_learning', 'RAVLT_forgetting', 'RAVLT_perc_forgetting', 'FAQ',
#        'MOCA', 'EcogPtMem', 'EcogPtLang', 'EcogPtVisspat', 'EcogPtPlan',
#        'EcogPtOrgan', 'EcogPtDivatt', 'EcogPtTotal', 'EcogSPMem', 'EcogSPLang',
#        'EcogSPVisspat', 'EcogSPPlan', 'EcogSPOrgan', 'EcogSPDivatt',
#        'EcogSPTotal', 'Ventricles', 'Hippocampus', 'WholeBrain', 'Entorhinal',
#        'Fusiform', 'MidTemp', 'ICV'],
#       dtype='object')
# 232 Index(['FDG', 'AV45', 'CDRSB', 'ADAS11', 'ADAS13', 'MMSE', 'RAVLT_immediate',
#        'RAVLT_learning', 'RAVLT_forgetting', 'RAVLT_perc_forgetting', 'FAQ',
#        'MOCA', 'EcogPtMem', 'EcogPtLang', 'EcogPtVisspat', 'EcogPtPlan',
#        'EcogPtOrgan', 'EcogPtDivatt', 'EcogPtTotal', 'EcogSPMem', 'EcogSPLang',
#        'EcogSPVisspat', 'EcogSPPlan', 'EcogSPOrgan', 'EcogSPDivatt',
#        'EcogSPTotal', 'Ventricles', 'Hippocampus', 'WholeBrain', 'Entorhinal',
#        'Fusiform', 'MidTemp', 'ICV'],
#       dtype='object')
# 233 Index(['FDG', 'AV45', 'Ventricles', 'Hippocampus', 'WholeBrain', 'Entorhinal',
#        'Fusiform', 'MidTemp', 'ICV'],
#       dtype='object')
# 234 Index(['FDG', 'AV45', 'CDRSB', 'ADAS11', 'ADAS13', 'MMSE', 'RAVLT_immediate',
#        'RAVLT_learning', 'RAVLT_forgetting', 'RAVLT_perc_forgetting', 'FAQ',
#        'MOCA', 'EcogPtMem', 'EcogPtLang', 'EcogPtVisspat', 'EcogPtPlan',
#        'EcogPtOrgan', 'EcogPtDivatt', 'EcogPtTotal', 'EcogSPMem', 'EcogSPLang',
#        'EcogSPVisspat', 'EcogSPPlan', 'EcogSPOrgan', 'EcogSPDivatt',
#        'EcogSPTotal'],
#       dtype='object')
# 236 Index(['FDG', 'AV45', 'CDRSB', 'ADAS11', 'ADAS13', 'MMSE', 'RAVLT_immediate',
#        'RAVLT_learning', 'RAVLT_forgetting', 'RAVLT_perc_forgetting', 'FAQ',
#        'MOCA', 'EcogPtMem', 'EcogPtLang', 'EcogPtVisspat', 'EcogPtPlan',
#        'EcogPtOrgan', 'EcogPtDivatt', 'EcogPtTotal', 'EcogSPMem', 'EcogSPLang',
#        'EcogSPVisspat', 'EcogSPPlan', 'EcogSPOrgan', 'EcogSPDivatt',
#        'EcogSPTotal', 'Ventricles', 'Hippocampus', 'WholeBrain', 'Entorhinal',
#        'Fusiform', 'MidTemp', 'ICV'],
#       dtype='object')
# 237 Index(['FDG', 'AV45', 'Ventricles', 'Hippocampus', 'WholeBrain', 'Entorhinal',
#        'Fusiform', 'MidTemp', 'ICV'],
#       dtype='object')
# 238 Index(['FDG', 'AV45', 'CDRSB', 'ADAS11', 'ADAS13', 'MMSE', 'RAVLT_immediate',
#        'RAVLT_learning', 'RAVLT_forgetting', 'RAVLT_perc_forgetting', 'FAQ',
#        'MOCA', 'EcogPtMem', 'EcogPtLang', 'EcogPtVisspat', 'EcogPtPlan',
#        'EcogPtOrgan', 'EcogPtDivatt', 'EcogPtTotal', 'EcogSPMem', 'EcogSPLang',
#        'EcogSPVisspat', 'EcogSPPlan', 'EcogSPOrgan', 'EcogSPDivatt',
#        'EcogSPTotal'],
#       dtype='object')
# 240 Index(['FDG', 'AV45', 'CDRSB', 'EcogSPMem', 'EcogSPLang', 'EcogSPVisspat',
#        'EcogSPOrgan', 'EcogSPDivatt', 'EcogSPTotal', 'Ventricles',
#        'Hippocampus', 'WholeBrain', 'Entorhinal', 'Fusiform', 'MidTemp', 'ICV',
#        'Hippocampus_bl'],
#       dtype='object')
# 241 Index(['FDG', 'AV45', 'CDRSB', 'ADAS11', 'ADAS13', 'MMSE', 'RAVLT_immediate',
#        'RAVLT_learning', 'RAVLT_forgetting', 'RAVLT_perc_forgetting', 'FAQ',
#        'MOCA', 'EcogPtMem', 'EcogPtLang', 'EcogPtVisspat', 'EcogPtPlan',
#        'EcogPtOrgan', 'EcogPtDivatt', 'EcogPtTotal', 'EcogSPMem', 'EcogSPLang',
#        'EcogSPVisspat', 'EcogSPPlan', 'EcogSPOrgan', 'EcogSPDivatt',
#        'EcogSPTotal', 'Hippocampus_bl'],
#       dtype='object')
# 242 Index(['Hippocampus', 'Hippocampus_bl'], dtype='object')
# 243 Index(['FDG', 'AV45'], dtype='object')
# 244 Index(['FDG', 'AV45', 'Ventricles', 'Hippocampus', 'WholeBrain', 'Entorhinal',
#        'Fusiform', 'MidTemp', 'ICV'],
#       dtype='object')
# 245 Index(['FDG', 'AV45', 'CDRSB', 'ADAS11', 'ADAS13', 'MMSE', 'RAVLT_immediate',
#        'RAVLT_learning', 'RAVLT_forgetting', 'RAVLT_perc_forgetting', 'FAQ',
#        'MOCA', 'EcogPtMem', 'EcogPtLang', 'EcogPtVisspat', 'EcogPtPlan',
#        'EcogPtOrgan', 'EcogPtDivatt', 'EcogPtTotal', 'EcogSPMem', 'EcogSPLang',
#        'EcogSPVisspat', 'EcogSPPlan', 'EcogSPOrgan', 'EcogSPDivatt',
#        'EcogSPTotal', 'Ventricles', 'Hippocampus', 'WholeBrain', 'Entorhinal',
#        'Fusiform', 'MidTemp'],
#       dtype='object')
# 247 Index(['FDG', 'CDRSB', 'EcogSPOrgan'], dtype='object')
# 248 Index(['FDG', 'AV45', 'Ventricles', 'Hippocampus', 'WholeBrain', 'Entorhinal',
#        'Fusiform', 'MidTemp', 'ICV'],
#       dtype='object')
# 249 Index(['FDG', 'AV45', 'CDRSB', 'ADAS11', 'ADAS13', 'MMSE', 'RAVLT_immediate',
#        'RAVLT_learning', 'RAVLT_forgetting', 'RAVLT_perc_forgetting', 'FAQ',
#        'MOCA', 'EcogPtMem', 'EcogPtLang', 'EcogPtVisspat', 'EcogPtPlan',
#        'EcogPtOrgan', 'EcogPtDivatt', 'EcogPtTotal', 'EcogSPMem', 'EcogSPLang',
#        'EcogSPVisspat', 'EcogSPPlan', 'EcogSPOrgan', 'EcogSPDivatt',
#        'EcogSPTotal'],
#       dtype='object')
# 251 Index(['FDG', 'Hippocampus_bl'], dtype='object')
# 252 Index(['FDG', 'AV45', 'Ventricles', 'Hippocampus', 'WholeBrain', 'Entorhinal',
#        'Fusiform', 'MidTemp', 'ICV', 'Hippocampus_bl'],
#       dtype='object')
# 253 Index(['FDG', 'AV45', 'CDRSB', 'ADAS11', 'ADAS13', 'MMSE', 'RAVLT_immediate',
#        'RAVLT_learning', 'RAVLT_forgetting', 'RAVLT_perc_forgetting', 'FAQ',
#        'MOCA', 'EcogPtMem', 'EcogPtLang', 'EcogPtVisspat', 'EcogPtPlan',
#        'EcogPtOrgan', 'EcogPtDivatt', 'EcogPtTotal', 'EcogSPMem', 'EcogSPLang',
#        'EcogSPVisspat', 'EcogSPPlan', 'EcogSPOrgan', 'EcogSPDivatt',
#        'EcogSPTotal', 'Hippocampus_bl'],
#       dtype='object')
# 254 Index(['Hippocampus', 'Hippocampus_bl'], dtype='object')
# 255 Index(['FDG', 'Ventricles', 'Hippocampus', 'WholeBrain', 'Entorhinal',
#        'Fusiform', 'MidTemp', 'ICV'],
#       dtype='object')
# 256 Index(['FDG', 'Ventricles', 'Hippocampus', 'WholeBrain', 'Entorhinal',
#        'Fusiform', 'MidTemp', 'ICV'],
#       dtype='object')
# 257 Index(['FDG', 'AV45', 'Ventricles', 'Hippocampus', 'WholeBrain', 'Entorhinal',
#        'Fusiform', 'MidTemp', 'ICV'],
#       dtype='object')
# 259 Index(['FDG'], dtype='object')
# 260 Index(['FDG', 'AV45', 'Ventricles', 'Hippocampus', 'WholeBrain', 'Entorhinal',
#        'Fusiform', 'MidTemp', 'ICV'],
#       dtype='object')
# 261 Index(['FDG', 'AV45', 'CDRSB', 'ADAS11', 'ADAS13', 'MMSE', 'RAVLT_immediate',
#        'RAVLT_learning', 'RAVLT_forgetting', 'RAVLT_perc_forgetting', 'FAQ',
#        'MOCA', 'EcogPtMem', 'EcogPtLang', 'EcogPtVisspat', 'EcogPtPlan',
#        'EcogPtOrgan', 'EcogPtDivatt', 'EcogPtTotal', 'EcogSPMem', 'EcogSPLang',
#        'EcogSPVisspat', 'EcogSPPlan', 'EcogSPOrgan', 'EcogSPDivatt',
#        'EcogSPTotal'],
#       dtype='object')
# 263 Index(['FDG', 'AV45', 'Ventricles', 'Hippocampus', 'WholeBrain', 'Entorhinal',
#        'Fusiform', 'MidTemp', 'ICV'],
#       dtype='object')
# 265 Index(['AV45', 'AV45_bl'], dtype='object')
# 266 Index(['FDG', 'AV45'], dtype='object')
# 267 Index(['FDG', 'AV45', 'Ventricles', 'Hippocampus', 'WholeBrain', 'Entorhinal',
#        'Fusiform', 'MidTemp', 'ICV'],
#       dtype='object')
# 268 Index(['FDG', 'AV45', 'CDRSB', 'ADAS11', 'ADAS13', 'MMSE', 'RAVLT_immediate',
#        'RAVLT_learning', 'RAVLT_forgetting', 'RAVLT_perc_forgetting', 'FAQ',
#        'MOCA', 'EcogPtMem', 'EcogPtLang', 'EcogPtVisspat', 'EcogPtPlan',
#        'EcogPtOrgan', 'EcogPtDivatt', 'EcogPtTotal', 'EcogSPMem', 'EcogSPLang',
#        'EcogSPVisspat', 'EcogSPPlan', 'EcogSPOrgan', 'EcogSPDivatt',
#        'EcogSPTotal'],
#       dtype='object')
# 271 Index(['FDG', 'AV45', 'EcogSPVisspat', 'Ventricles', 'Hippocampus',
#        'WholeBrain', 'Entorhinal', 'Fusiform', 'MidTemp', 'ICV',
#        'EcogSPOrgan_bl'],
#       dtype='object')
# 272 Index(['FDG', 'EcogSPDivatt', 'EcogSPOrgan_bl'], dtype='object')
# 273 Index(['FDG', 'AV45', 'EcogSPOrgan', 'EcogSPDivatt', 'EcogSPOrgan_bl'], dtype='object')
# 274 Index(['FDG', 'AV45', 'Ventricles', 'Hippocampus', 'WholeBrain', 'Entorhinal',
#        'Fusiform', 'MidTemp', 'ICV', 'EcogSPOrgan_bl'],
#       dtype='object')
# 275 Index(['FDG', 'AV45', 'CDRSB', 'ADAS11', 'ADAS13', 'MMSE', 'RAVLT_immediate',
#        'RAVLT_learning', 'RAVLT_forgetting', 'RAVLT_perc_forgetting', 'FAQ',
#        'MOCA', 'EcogPtMem', 'EcogPtLang', 'EcogPtVisspat', 'EcogPtPlan',
#        'EcogPtOrgan', 'EcogPtDivatt', 'EcogPtTotal', 'EcogSPMem', 'EcogSPLang',
#        'EcogSPVisspat', 'EcogSPPlan', 'EcogSPOrgan', 'EcogSPDivatt',
#        'EcogSPTotal', 'EcogSPOrgan_bl'],
#       dtype='object')
# 276 Index(['EcogSPOrgan', 'EcogSPOrgan_bl'], dtype='object')
# 277 Index(['FDG', 'Ventricles', 'Hippocampus', 'WholeBrain', 'Entorhinal',
#        'Fusiform', 'MidTemp', 'ICV'],
#       dtype='object')
# 278 Index(['FDG', 'AV45', 'Entorhinal', 'Fusiform', 'MidTemp'], dtype='object')
# 279 Index(['FDG', 'AV45', 'Ventricles', 'Hippocampus', 'WholeBrain', 'Entorhinal',
#        'Fusiform', 'MidTemp', 'ICV'],
#       dtype='object')
# 280 Index(['FDG', 'AV45', 'CDRSB', 'ADAS11', 'ADAS13', 'MMSE', 'RAVLT_immediate',
#        'RAVLT_learning', 'RAVLT_forgetting', 'RAVLT_perc_forgetting', 'FAQ',
#        'MOCA', 'EcogPtMem', 'EcogPtLang', 'EcogPtVisspat', 'EcogPtPlan',
#        'EcogPtOrgan', 'EcogPtDivatt', 'EcogPtTotal', 'EcogSPMem', 'EcogSPLang',
#        'EcogSPVisspat', 'EcogSPPlan', 'EcogSPOrgan', 'EcogSPDivatt',
#        'EcogSPTotal'],
#       dtype='object')
# 282 Index(['FDG'], dtype='object')
# 283 Index(['FDG', 'AV45', 'Ventricles', 'Hippocampus', 'WholeBrain', 'Entorhinal',
#        'Fusiform', 'MidTemp', 'ICV'],
#       dtype='object')
# 284 Index(['FDG', 'AV45', 'CDRSB', 'ADAS11', 'ADAS13', 'MMSE', 'RAVLT_immediate',
#        'RAVLT_learning', 'RAVLT_forgetting', 'RAVLT_perc_forgetting', 'FAQ',
#        'MOCA', 'EcogPtMem', 'EcogPtLang', 'EcogPtVisspat', 'EcogPtPlan',
#        'EcogPtOrgan', 'EcogPtDivatt', 'EcogPtTotal', 'EcogSPMem', 'EcogSPLang',
#        'EcogSPVisspat', 'EcogSPPlan', 'EcogSPOrgan', 'EcogSPDivatt',
# ...
#        'EcogPtDivatt_bl', 'EcogPtTotal_bl', 'EcogSPMem_bl', 'EcogSPLang_bl',
#        'EcogSPVisspat_bl', 'EcogSPPlan_bl', 'EcogSPOrgan_bl',
#        'EcogSPDivatt_bl', 'EcogSPTotal_bl', 'FDG_bl', 'AV45_bl'],
#       dtype='object')
# 6889 Index(['FDG', 'AV45', 'Ventricles', 'Hippocampus', 'WholeBrain', 'Entorhinal',
#        'Fusiform', 'MidTemp', 'ICV', 'MOCA_bl', 'EcogPtMem_bl',
#        'EcogPtLang_bl', 'EcogPtVisspat_bl', 'EcogPtPlan_bl', 'EcogPtOrgan_bl',
#        'EcogPtDivatt_bl', 'EcogPtTotal_bl', 'EcogSPMem_bl', 'EcogSPLang_bl',
#        'EcogSPVisspat_bl', 'EcogSPPlan_bl', 'EcogSPOrgan_bl',
#        'EcogSPDivatt_bl', 'EcogSPTotal_bl', 'AV45_bl'],
#       dtype='object')
# 6890 Index(['FDG', 'AV45', 'CDRSB', 'ADAS11', 'ADAS13', 'MMSE', 'RAVLT_immediate',
#        'RAVLT_learning', 'RAVLT_forgetting', 'RAVLT_perc_forgetting', 'FAQ',
#        'MOCA', 'EcogPtMem', 'EcogPtLang', 'EcogPtVisspat', 'EcogPtPlan',
#        'EcogPtOrgan', 'EcogPtDivatt', 'EcogPtTotal', 'EcogSPMem', 'EcogSPLang',
#        'EcogSPVisspat', 'EcogSPPlan', 'EcogSPOrgan', 'EcogSPDivatt',
#        'EcogSPTotal', 'Ventricles', 'Hippocampus', 'WholeBrain', 'Entorhinal',
#        'Fusiform', 'MidTemp', 'ICV', 'MOCA_bl', 'EcogPtMem_bl',
#        'EcogPtLang_bl', 'EcogPtVisspat_bl', 'EcogPtPlan_bl', 'EcogPtOrgan_bl',
#        'EcogPtDivatt_bl', 'EcogPtTotal_bl', 'EcogSPMem_bl', 'EcogSPLang_bl',
#        'EcogSPVisspat_bl', 'EcogSPPlan_bl', 'EcogSPOrgan_bl',
#        'EcogSPDivatt_bl', 'EcogSPTotal_bl', 'AV45_bl'],
#       dtype='object')
# 6891 Index(['FDG', 'AV45', 'Ventricles', 'Hippocampus', 'WholeBrain', 'Entorhinal',
#        'Fusiform', 'MidTemp', 'ICV', 'MOCA_bl', 'EcogPtMem_bl',
#        'EcogPtLang_bl', 'EcogPtVisspat_bl', 'EcogPtPlan_bl', 'EcogPtOrgan_bl',
#        'EcogPtDivatt_bl', 'EcogPtTotal_bl', 'EcogSPMem_bl', 'EcogSPLang_bl',
#        'EcogSPVisspat_bl', 'EcogSPPlan_bl', 'EcogSPOrgan_bl',
#        'EcogSPDivatt_bl', 'EcogSPTotal_bl', 'AV45_bl'],
#       dtype='object')
# 6892 Index(['FDG', 'AV45', 'CDRSB', 'ADAS11', 'ADAS13', 'MMSE', 'RAVLT_immediate',
#        'RAVLT_learning', 'RAVLT_forgetting', 'RAVLT_perc_forgetting', 'FAQ',
#        'MOCA', 'EcogPtMem', 'EcogPtLang', 'EcogPtVisspat', 'EcogPtPlan',
#        'EcogPtOrgan', 'EcogPtDivatt', 'EcogPtTotal', 'EcogSPMem', 'EcogSPLang',
#        'EcogSPVisspat', 'EcogSPPlan', 'EcogSPOrgan', 'EcogSPDivatt',
#        'EcogSPTotal', 'Ventricles', 'Hippocampus', 'WholeBrain', 'Entorhinal',
#        'Fusiform', 'MidTemp', 'ICV', 'MOCA_bl', 'EcogPtMem_bl',
#        'EcogPtLang_bl', 'EcogPtVisspat_bl', 'EcogPtPlan_bl', 'EcogPtOrgan_bl',
#        'EcogPtDivatt_bl', 'EcogPtTotal_bl', 'EcogSPMem_bl', 'EcogSPLang_bl',
#        'EcogSPVisspat_bl', 'EcogSPPlan_bl', 'EcogSPOrgan_bl',
#        'EcogSPDivatt_bl', 'EcogSPTotal_bl', 'AV45_bl'],
#       dtype='object')
# 6893 Index(['FDG', 'AV45', 'Ventricles', 'Hippocampus', 'WholeBrain', 'Entorhinal',
#        'Fusiform', 'MidTemp', 'ICV', 'MOCA_bl', 'EcogPtMem_bl',
#        'EcogPtLang_bl', 'EcogPtVisspat_bl', 'EcogPtPlan_bl', 'EcogPtOrgan_bl',
#        'EcogPtDivatt_bl', 'EcogPtTotal_bl', 'EcogSPMem_bl', 'EcogSPLang_bl',
#        'EcogSPVisspat_bl', 'EcogSPPlan_bl', 'EcogSPOrgan_bl',
#        'EcogSPDivatt_bl', 'EcogSPTotal_bl', 'AV45_bl'],
#       dtype='object')
# 6894 Index(['FDG', 'AV45', 'CDRSB', 'ADAS11', 'ADAS13', 'MMSE', 'RAVLT_immediate',
#        'RAVLT_learning', 'RAVLT_forgetting', 'RAVLT_perc_forgetting', 'FAQ',
#        'MOCA', 'EcogPtMem', 'EcogPtLang', 'EcogPtVisspat', 'EcogPtPlan',
#        'EcogPtOrgan', 'EcogPtDivatt', 'EcogPtTotal', 'EcogSPMem', 'EcogSPLang',
#        'EcogSPVisspat', 'EcogSPPlan', 'EcogSPOrgan', 'EcogSPDivatt',
#        'EcogSPTotal', 'Ventricles', 'Hippocampus', 'WholeBrain', 'Entorhinal',
#        'Fusiform', 'MidTemp', 'ICV', 'MOCA_bl', 'EcogPtMem_bl',
#        'EcogPtLang_bl', 'EcogPtVisspat_bl', 'EcogPtPlan_bl', 'EcogPtOrgan_bl',
#        'EcogPtDivatt_bl', 'EcogPtTotal_bl', 'EcogSPMem_bl', 'EcogSPLang_bl',
#        'EcogSPVisspat_bl', 'EcogSPPlan_bl', 'EcogSPOrgan_bl',
#        'EcogSPDivatt_bl', 'EcogSPTotal_bl', 'AV45_bl'],
#       dtype='object')
# 6895 Index(['FDG', 'AV45', 'Ventricles', 'Hippocampus', 'WholeBrain', 'Entorhinal',
#        'Fusiform', 'MidTemp', 'ICV', 'MOCA_bl', 'EcogPtMem_bl',
#        'EcogPtLang_bl', 'EcogPtVisspat_bl', 'EcogPtPlan_bl', 'EcogPtOrgan_bl',
#        'EcogPtDivatt_bl', 'EcogPtTotal_bl', 'EcogSPMem_bl', 'EcogSPLang_bl',
#        'EcogSPVisspat_bl', 'EcogSPPlan_bl', 'EcogSPOrgan_bl',
#        'EcogSPDivatt_bl', 'EcogSPTotal_bl', 'AV45_bl'],
#       dtype='object')
# 6896 Index(['FDG', 'AV45', 'CDRSB', 'ADAS11', 'ADAS13', 'MMSE', 'RAVLT_immediate',
#        'RAVLT_learning', 'RAVLT_forgetting', 'RAVLT_perc_forgetting', 'FAQ',
#        'MOCA', 'EcogPtMem', 'EcogPtLang', 'EcogPtVisspat', 'EcogPtPlan',
#        'EcogPtOrgan', 'EcogPtDivatt', 'EcogPtTotal', 'EcogSPMem', 'EcogSPLang',
#        'EcogSPVisspat', 'EcogSPPlan', 'EcogSPOrgan', 'EcogSPDivatt',
#        'EcogSPTotal', 'Ventricles', 'Hippocampus', 'WholeBrain', 'Entorhinal',
#        'Fusiform', 'MidTemp', 'ICV', 'MOCA_bl', 'EcogPtMem_bl',
#        'EcogPtLang_bl', 'EcogPtVisspat_bl', 'EcogPtPlan_bl', 'EcogPtOrgan_bl',
#        'EcogPtDivatt_bl', 'EcogPtTotal_bl', 'EcogSPMem_bl', 'EcogSPLang_bl',
#        'EcogSPVisspat_bl', 'EcogSPPlan_bl', 'EcogSPOrgan_bl',
#        'EcogSPDivatt_bl', 'EcogSPTotal_bl', 'AV45_bl'],
#       dtype='object')
# 6897 Index(['FDG', 'AV45', 'Ventricles', 'Hippocampus', 'WholeBrain', 'Entorhinal',
#        'Fusiform', 'MidTemp', 'ICV', 'MOCA_bl', 'EcogPtMem_bl',
#        'EcogPtLang_bl', 'EcogPtVisspat_bl', 'EcogPtPlan_bl', 'EcogPtOrgan_bl',
#        'EcogPtDivatt_bl', 'EcogPtTotal_bl', 'EcogSPMem_bl', 'EcogSPLang_bl',
#        'EcogSPVisspat_bl', 'EcogSPPlan_bl', 'EcogSPOrgan_bl',
#        'EcogSPDivatt_bl', 'EcogSPTotal_bl', 'AV45_bl'],
#       dtype='object')
# 6898 Index(['FDG', 'AV45', 'ADAS11', 'ADAS13', 'RAVLT_immediate', 'RAVLT_learning',
#        'RAVLT_forgetting', 'RAVLT_perc_forgetting', 'MOCA', 'EcogPtMem',
#        'EcogPtLang', 'EcogPtVisspat', 'EcogPtPlan', 'EcogPtOrgan',
#        'EcogPtDivatt', 'EcogPtTotal', 'EcogSPMem', 'EcogSPLang',
#        'EcogSPVisspat', 'EcogSPPlan', 'EcogSPOrgan', 'EcogSPDivatt',
#        'EcogSPTotal', 'Ventricles', 'Hippocampus', 'WholeBrain', 'Entorhinal',
#        'Fusiform', 'MidTemp', 'ICV', 'MOCA_bl', 'EcogPtMem_bl',
#        'EcogPtLang_bl', 'EcogPtVisspat_bl', 'EcogPtPlan_bl', 'EcogPtOrgan_bl',
#        'EcogPtDivatt_bl', 'EcogPtTotal_bl', 'EcogSPMem_bl', 'EcogSPLang_bl',
#        'EcogSPVisspat_bl', 'EcogSPPlan_bl', 'EcogSPOrgan_bl',
#        'EcogSPDivatt_bl', 'EcogSPTotal_bl', 'AV45_bl'],
#       dtype='object')
# 6899 Index(['FDG', 'AV45', 'CDRSB', 'ADAS11', 'ADAS13', 'MMSE', 'RAVLT_immediate',
#        'RAVLT_learning', 'RAVLT_forgetting', 'RAVLT_perc_forgetting', 'FAQ',
#        'MOCA', 'EcogPtMem', 'EcogPtLang', 'EcogPtVisspat', 'EcogPtPlan',
#        'EcogPtOrgan', 'EcogPtDivatt', 'EcogPtTotal', 'EcogSPMem', 'EcogSPLang',
#        'EcogSPVisspat', 'EcogSPPlan', 'EcogSPOrgan', 'EcogSPDivatt',
#        'EcogSPTotal', 'Ventricles', 'Hippocampus', 'WholeBrain', 'Entorhinal',
#        'Fusiform', 'MidTemp', 'ICV', 'MOCA_bl', 'EcogPtMem_bl',
#        'EcogPtLang_bl', 'EcogPtVisspat_bl', 'EcogPtPlan_bl', 'EcogPtOrgan_bl',
#        'EcogPtDivatt_bl', 'EcogPtTotal_bl', 'EcogSPMem_bl', 'EcogSPLang_bl',
#        'EcogSPVisspat_bl', 'EcogSPPlan_bl', 'EcogSPOrgan_bl',
#        'EcogSPDivatt_bl', 'EcogSPTotal_bl', 'AV45_bl'],
#       dtype='object')
# 6900 Index(['FDG', 'AV45', 'Ventricles', 'Hippocampus', 'WholeBrain', 'Entorhinal',
#        'Fusiform', 'MidTemp', 'ICV', 'MOCA_bl', 'EcogPtMem_bl',
#        'EcogPtLang_bl', 'EcogPtVisspat_bl', 'EcogPtPlan_bl', 'EcogPtOrgan_bl',
#        'EcogPtDivatt_bl', 'EcogPtTotal_bl', 'EcogSPMem_bl', 'EcogSPLang_bl',
#        'EcogSPVisspat_bl', 'EcogSPPlan_bl', 'EcogSPOrgan_bl',
#        'EcogSPDivatt_bl', 'EcogSPTotal_bl', 'AV45_bl'],
#       dtype='object')
# 6901 Index(['FDG', 'AV45', 'CDRSB', 'ADAS11', 'ADAS13', 'MMSE', 'RAVLT_immediate',
#        'RAVLT_learning', 'RAVLT_forgetting', 'RAVLT_perc_forgetting', 'FAQ',
#        'MOCA', 'EcogPtMem', 'EcogPtLang', 'EcogPtVisspat', 'EcogPtPlan',
#        'EcogPtOrgan', 'EcogPtDivatt', 'EcogPtTotal', 'EcogSPMem', 'EcogSPLang',
#        'EcogSPVisspat', 'EcogSPPlan', 'EcogSPOrgan', 'EcogSPDivatt',
#        'EcogSPTotal', 'Ventricles', 'Hippocampus', 'WholeBrain', 'Entorhinal',
#        'Fusiform', 'MidTemp', 'ICV', 'MOCA_bl', 'EcogPtMem_bl',
#        'EcogPtLang_bl', 'EcogPtVisspat_bl', 'EcogPtPlan_bl', 'EcogPtOrgan_bl',
#        'EcogPtDivatt_bl', 'EcogPtTotal_bl', 'EcogSPMem_bl', 'EcogSPLang_bl',
#        'EcogSPVisspat_bl', 'EcogSPPlan_bl', 'EcogSPOrgan_bl',
#        'EcogSPDivatt_bl', 'EcogSPTotal_bl', 'AV45_bl'],
#       dtype='object')
# 6902 Index(['FDG', 'AV45', 'Ventricles', 'Hippocampus', 'WholeBrain', 'Entorhinal',
#        'Fusiform', 'MidTemp', 'ICV', 'MOCA_bl', 'EcogPtMem_bl',
#        'EcogPtLang_bl', 'EcogPtVisspat_bl', 'EcogPtPlan_bl', 'EcogPtOrgan_bl',
#        'EcogPtDivatt_bl', 'EcogPtTotal_bl', 'EcogSPMem_bl', 'EcogSPLang_bl',
#        'EcogSPVisspat_bl', 'EcogSPPlan_bl', 'EcogSPOrgan_bl',
#        'EcogSPDivatt_bl', 'EcogSPTotal_bl', 'AV45_bl'],
#       dtype='object')
# 6903 Index(['FDG', 'AV45', 'CDRSB', 'ADAS11', 'ADAS13', 'MMSE', 'RAVLT_immediate',
#        'RAVLT_learning', 'RAVLT_forgetting', 'RAVLT_perc_forgetting', 'FAQ',
#        'MOCA', 'EcogPtMem', 'EcogPtLang', 'EcogPtVisspat', 'EcogPtPlan',
#        'EcogPtOrgan', 'EcogPtDivatt', 'EcogPtTotal', 'EcogSPMem', 'EcogSPLang',
#        'EcogSPVisspat', 'EcogSPPlan', 'EcogSPOrgan', 'EcogSPDivatt',
#        'EcogSPTotal', 'Ventricles', 'Hippocampus', 'WholeBrain', 'Entorhinal',
#        'Fusiform', 'MidTemp', 'ICV', 'MOCA_bl', 'EcogPtMem_bl',
#        'EcogPtLang_bl', 'EcogPtVisspat_bl', 'EcogPtPlan_bl', 'EcogPtOrgan_bl',
#        'EcogPtDivatt_bl', 'EcogPtTotal_bl', 'EcogSPMem_bl', 'EcogSPLang_bl',
#        'EcogSPVisspat_bl', 'EcogSPPlan_bl', 'EcogSPOrgan_bl',
#        'EcogSPDivatt_bl', 'EcogSPTotal_bl', 'AV45_bl'],
#       dtype='object')
# 6904 Index(['FDG', 'AV45', 'Ventricles', 'Hippocampus', 'WholeBrain', 'Entorhinal',
#        'Fusiform', 'MidTemp', 'ICV', 'MOCA_bl', 'EcogPtMem_bl',
#        'EcogPtLang_bl', 'EcogPtVisspat_bl', 'EcogPtPlan_bl', 'EcogPtOrgan_bl',
#        'EcogPtDivatt_bl', 'EcogPtTotal_bl', 'EcogSPMem_bl', 'EcogSPLang_bl',
#        'EcogSPVisspat_bl', 'EcogSPPlan_bl', 'EcogSPOrgan_bl',
#        'EcogSPDivatt_bl', 'EcogSPTotal_bl', 'AV45_bl'],
#       dtype='object')
# 6905 Index(['FDG', 'AV45', 'Ventricles', 'Hippocampus', 'WholeBrain', 'Entorhinal',
#        'Fusiform', 'MidTemp', 'ICV'],
#       dtype='object')
# 6906 Index(['FDG', 'AV45', 'CDRSB', 'ADAS11', 'ADAS13', 'MMSE', 'RAVLT_immediate',
#        'RAVLT_learning', 'RAVLT_forgetting', 'RAVLT_perc_forgetting', 'FAQ',
#        'MOCA', 'EcogPtMem', 'EcogPtLang', 'EcogPtVisspat', 'EcogPtPlan',
#        'EcogPtOrgan', 'EcogPtDivatt', 'EcogPtTotal', 'EcogSPMem', 'EcogSPLang',
#        'EcogSPVisspat', 'EcogSPPlan', 'EcogSPOrgan', 'EcogSPDivatt',
#        'EcogSPTotal', 'Ventricles', 'Hippocampus', 'WholeBrain', 'Entorhinal',
#        'Fusiform', 'MidTemp', 'ICV', 'MOCA_bl', 'EcogPtMem_bl',
#        'EcogPtLang_bl', 'EcogPtVisspat_bl', 'EcogPtPlan_bl', 'EcogPtOrgan_bl',
#        'EcogPtDivatt_bl', 'EcogPtTotal_bl', 'EcogSPMem_bl', 'EcogSPLang_bl',
#        'EcogSPVisspat_bl', 'EcogSPPlan_bl', 'EcogSPOrgan_bl',
#        'EcogSPDivatt_bl', 'EcogSPTotal_bl', 'AV45_bl'],
#       dtype='object')
# 6907 Index(['FDG', 'AV45', 'CDRSB', 'ADAS11', 'ADAS13', 'MMSE', 'RAVLT_immediate',
#        'RAVLT_learning', 'RAVLT_forgetting', 'RAVLT_perc_forgetting', 'FAQ',
#        'MOCA', 'EcogSPMem', 'EcogSPLang', 'EcogSPVisspat', 'EcogSPPlan',
#        'EcogSPOrgan', 'EcogSPDivatt', 'EcogSPTotal', 'Ventricles',
#        'Hippocampus', 'WholeBrain', 'Entorhinal', 'Fusiform', 'MidTemp',
#        'ICV'],
#       dtype='object')
# 6908 Index(['FDG', 'AV45', 'EcogSPOrgan', 'Ventricles', 'Hippocampus', 'WholeBrain',
#        'Entorhinal', 'Fusiform', 'MidTemp', 'ICV', 'EcogPtOrgan_bl'],
#       dtype='object')
# 6909 Index(['FDG', 'AV45', 'Ventricles', 'Hippocampus', 'WholeBrain', 'Entorhinal',
#        'Fusiform', 'MidTemp', 'ICV', 'Ventricles_bl', 'WholeBrain_bl',
#        'Entorhinal_bl', 'Fusiform_bl', 'MidTemp_bl', 'MOCA_bl', 'EcogPtMem_bl',
#        'EcogPtLang_bl', 'EcogPtVisspat_bl', 'EcogPtPlan_bl', 'EcogPtOrgan_bl',
#        'EcogPtDivatt_bl', 'EcogPtTotal_bl'],
#       dtype='object')
# 6910 Index(['FDG', 'AV45', 'CDRSB', 'FAQ', 'EcogSPMem', 'EcogSPLang',
#        'EcogSPVisspat', 'EcogSPPlan', 'EcogSPOrgan', 'EcogSPDivatt',
#        'EcogSPTotal', 'Ventricles', 'Hippocampus', 'WholeBrain', 'Entorhinal',
#        'Fusiform', 'MidTemp', 'ICV', 'Ventricles_bl', 'WholeBrain_bl',
#        'Entorhinal_bl', 'Fusiform_bl', 'MidTemp_bl', 'MOCA_bl', 'EcogPtMem_bl',
#        'EcogPtLang_bl', 'EcogPtVisspat_bl', 'EcogPtPlan_bl', 'EcogPtOrgan_bl',
#        'EcogPtDivatt_bl', 'EcogPtTotal_bl'],
#       dtype='object')
# 6911 Index(['EcogSPDivatt', 'EcogSPDivatt_bl'], dtype='object')
# 6912 Index(['FDG', 'AV45', 'Ventricles', 'Hippocampus', 'WholeBrain', 'Entorhinal',
#        'Fusiform', 'MidTemp', 'ICV', 'EcogSPDivatt_bl'],
#       dtype='object')
# 6913 Index(['FDG', 'AV45', 'ADAS13', 'Ventricles', 'Hippocampus', 'WholeBrain',
#        'Entorhinal', 'Fusiform', 'MidTemp', 'ICV', 'EcogSPDivatt_bl'],
#       dtype='object')
# 6915 Index(['FDG', 'Ventricles', 'Hippocampus', 'WholeBrain', 'Entorhinal',
#        'Fusiform', 'MidTemp', 'ICV'],
#       dtype='object')
# 6916 Index(['Ventricles', 'WholeBrain', 'Entorhinal', 'Fusiform', 'MidTemp',
#        'Ventricles_bl', 'WholeBrain_bl', 'Entorhinal_bl', 'Fusiform_bl',
#        'MidTemp_bl'],
#       dtype='object')
# 6917 Index(['FDG', 'Ventricles', 'Hippocampus', 'WholeBrain', 'Entorhinal',
#        'Fusiform', 'MidTemp', 'ICV', 'Ventricles_bl', 'WholeBrain_bl',
#        'Entorhinal_bl', 'Fusiform_bl', 'MidTemp_bl'],
#       dtype='object')
# 6919 Index(['FDG', 'AV45', 'Ventricles', 'Hippocampus', 'WholeBrain', 'Entorhinal',
#        'Fusiform', 'MidTemp', 'ICV'],
#       dtype='object')
# 6920 Index(['FDG', 'Ventricles', 'Hippocampus', 'WholeBrain', 'Entorhinal',
#        'Fusiform', 'MidTemp', 'ICV'],
#       dtype='object')
# 6922 Index(['FDG', 'AV45'], dtype='object')
# 6923 Index(['FDG', 'Ventricles', 'Hippocampus', 'WholeBrain', 'Entorhinal',
#        'Fusiform', 'MidTemp', 'ICV'],
#       dtype='object')
# 6925 Index(['FDG', 'AV45', 'Ventricles', 'Hippocampus', 'WholeBrain', 'Entorhinal',
#        'Fusiform', 'MidTemp', 'ICV'],
#       dtype='object')
# 6926 Index(['FDG'], dtype='object')
# 6928 Index(['FDG', 'AV45', 'Ventricles', 'Hippocampus', 'WholeBrain', 'Entorhinal',
#        'Fusiform', 'MidTemp', 'ICV'],
#       dtype='object')
# 6929 Index(['FDG'], dtype='object')
# 6930 Index(['AV45', 'AV45_bl'], dtype='object')
# 6931 Index(['FDG', 'CDRSB', 'EcogSPOrgan', 'Ventricles', 'Hippocampus',
#        'WholeBrain', 'Entorhinal', 'Fusiform', 'MidTemp', 'ICV', 'AV45_bl'],
#       dtype='object')
# 6932 Index(['Ventricles', 'WholeBrain', 'Entorhinal', 'Fusiform', 'MidTemp',
#        'Ventricles_bl', 'WholeBrain_bl', 'Entorhinal_bl', 'Fusiform_bl',
#        'MidTemp_bl'],
#       dtype='object')
# 6933 Index(['FDG', 'AV45', 'CDRSB', 'ADAS11', 'ADAS13', 'MMSE', 'RAVLT_immediate',
#        'RAVLT_learning', 'RAVLT_forgetting', 'RAVLT_perc_forgetting', 'FAQ',
#        'MOCA', 'EcogPtMem', 'EcogPtLang', 'EcogPtVisspat', 'EcogPtPlan',
#        'EcogPtOrgan', 'EcogPtDivatt', 'EcogPtTotal', 'EcogSPMem', 'EcogSPLang',
#        'EcogSPVisspat', 'EcogSPPlan', 'EcogSPOrgan', 'EcogSPDivatt',
#        'EcogSPTotal', 'Ventricles', 'Hippocampus', 'WholeBrain', 'Entorhinal',
#        'Fusiform', 'MidTemp', 'ICV', 'Ventricles_bl', 'WholeBrain_bl',
#        'Entorhinal_bl', 'Fusiform_bl', 'MidTemp_bl'],
#       dtype='object')
# 6934 Index(['FDG', 'Ventricles', 'Hippocampus', 'WholeBrain', 'Entorhinal',
#        'Fusiform', 'MidTemp', 'ICV', 'Ventricles_bl', 'WholeBrain_bl',
#        'Entorhinal_bl', 'Fusiform_bl', 'MidTemp_bl'],
#       dtype='object')
# 6936 Index(['FDG', 'Ventricles', 'Hippocampus', 'WholeBrain', 'Entorhinal',
#        'Fusiform', 'MidTemp', 'ICV'],
#       dtype='object')

# %%
ADNI2_missing.shape
# Out:
# (6937, 120)

# %%
ADNI2_missing.columns[0:3]
# Out:
# Index(['AGE', 'FDG', 'AV45'], dtype='object')

# %%
np.sum(np.sum(ADNI2_missing.isnull()))
# Out:
# 0

# %%
ADNI2_missing.to_csv(path_or_buf='ADNI2_mb_impute_v3.csv', index=False)

# %%
#ADNI2_missing.to_csv(path_or_buf='ADNI2_mb_impute.csv', index=False)

# %% [markdown]
# # Below are More Preliminary Exploration by Carlo

# %%
## Drop the predictors that have more than 50% missing (thresh parameter)

ADNI2_clean= ADNI2.dropna(axis=1, how='any', thresh=len(ADNI2['DX_bl'])/2, inplace=False)
print("Shape of ADNI2 before dropping columns with NaN>50%")
print(ADNI2.shape)
print("\n")
print("Shape of ADNI2 after dropping columns with NaN>50%")
print(ADNI2_clean.shape)
# Out:
# Shape of ADNI2 before dropping columns with NaN>50%
# (6937, 94)
#
#
# Shape of ADNI2 after dropping columns with NaN>50%
# (6937, 85)

# %%
ADNI2_clean_remove_all_missing = ADNI2.dropna(axis=1, how='any', thresh=len(ADNI2['DX_bl']), inplace=False)

# %%
ADNI2_clean_remove_all_missing.shape
# Out:
# (6937, 19)

# %%
np.sum(np.sum(ADNI2_clean_remove_all_missing.isnull()))
# Out:
# 0

# %%
ADNI2_clean_remove_all_missing.to_json(path_or_buf='ADNI2_clean_remove_all_missing.json' )

# %%
with open("ADNI2_clean_remove_all_missing.json") as json_file: 
    ADNI2_clean_remove_all_missing_load = pd.read_json(path_or_buf='ADNI2_clean_remove_all_missing.json')

# %%
ADNI2_clean_remove_all_missing_load.head()
# Out:
#         AGE  CDRSB_bl COLPROT DX_bl    EXAMDATE EXAMDATE_bl   M  MMSE_bl  \
# 10000  55.0       1.0   ADNI2  LMCI  2012-01-26  2011-07-27   6       28
# 10001  55.0       1.0   ADNI2  LMCI  2011-11-02  2011-07-27   3       28
# 10002  55.0       1.0   ADNI2  LMCI  2011-07-27  2011-07-27   0       28
# 10003  70.8       0.0   ADNI2    CN  2015-07-29  2011-07-22  48       30
# 10004  70.8       0.0   ADNI2    CN  2014-01-16  2011-07-22  30       30
#
#        Month  Month_bl ORIGPROT  PTEDUCAT PTGENDER        PTID   RID  SITE  \
# 10000      6   6.00000    ADNI2        14   Female  035_S_4114  4114    35
# 10001      3   3.21311    ADNI2        14   Female  035_S_4114  4114    35
# 10002      0   0.00000    ADNI2        14   Female  035_S_4114  4114    35
# 10003     48  48.13110    ADNI2        18   Female  011_S_4105  4105    11
# 10004     30  29.80330    ADNI2        18   Female  011_S_4105  4105    11
#
#       VISCODE  Years_bl           update_stamp
# 10000     m06  0.501027  2017-10-06 23:19:54.0
# 10001     m03  0.268309  2017-08-29 23:07:16.0
# 10002      bl  0.000000  2017-10-06 23:19:54.0
# 10003     m48  4.019170  2017-10-06 23:19:54.0
# 10004     m30  2.488710  2017-08-29 23:07:16.0

# %%
# The percentage for -4 and -1 is really small, so in order to make things easier in the imputation, I just delete these
# observations
ADNI2_clean = ADNI2_clean.drop(ADNI2_clean[ADNI2_clean.values == -4].index)
print("Shape of ADNI2 after dropping observations containing -4")
print(ADNI2_clean.shape)
print("\n")

ADNI2_clean = ADNI2_clean.drop(ADNI2_clean[ADNI2_clean.values == -1 ].index)
print("Shape of ADNI2 after dropping observations containing -1")
print(ADNI2_clean.shape)
# Out:
# Shape of ADNI2 after dropping observations containing -4
# (6933, 85)
#
#
# Shape of ADNI2 after dropping observations containing -1
# (6690, 85)

# %%
#Check the unique values for each predictor. 
for col in ADNI2_clean.columns:
    print('unique values for', col , len(ADNI2_clean[col].value_counts()))
# Out:
# unique values for RID 1154
# unique values for PTID 1154
# unique values for VISCODE 23
# unique values for SITE 58
# unique values for COLPROT 1
# unique values for ORIGPROT 3
# unique values for EXAMDATE 1345
# unique values for DX_bl 5
# unique values for AGE 293
# unique values for PTGENDER 2
# unique values for PTEDUCAT 14
# unique values for PTETHCAT 2
# unique values for PTRACCAT 6
# unique values for PTMARRY 4
# unique values for APOE4 3
# unique values for CDRSB 28
# unique values for ADAS11 62
# unique values for ADAS13 78
# unique values for MMSE 29
# unique values for RAVLT_immediate 76
# unique values for RAVLT_learning 18
# unique values for RAVLT_forgetting 20
# unique values for RAVLT_perc_forgetting 82
# unique values for FAQ 31
# unique values for MOCA 31
# unique values for EcogPtMem 57
# unique values for EcogPtLang 68
# unique values for EcogPtVisspat 51
# unique values for EcogPtPlan 29
# unique values for EcogPtOrgan 37
# unique values for EcogPtDivatt 19
# unique values for EcogPtTotal 474
# unique values for EcogSPMem 57
# unique values for EcogSPLang 73
# unique values for EcogSPVisspat 54
# unique values for EcogSPPlan 31
# unique values for EcogSPOrgan 37
# unique values for EcogSPDivatt 19
# unique values for EcogSPTotal 681
# unique values for FSVERSION 2
# unique values for Hippocampus 2351
# unique values for WholeBrain 3418
# unique values for ICV 3589
# unique values for DX 3
# unique values for EXAMDATE_bl 680
# unique values for CDRSB_bl 17
# unique values for ADAS11_bl 75
# unique values for ADAS13_bl 102
# unique values for MMSE_bl 12
# unique values for RAVLT_immediate_bl 66
# unique values for RAVLT_learning_bl 14
# unique values for RAVLT_forgetting_bl 18
# unique values for RAVLT_perc_forgetting_bl 71
# unique values for FAQ_bl 29
# unique values for FLDSTRENG_bl 2
# unique values for FSVERSION_bl 2
# unique values for Ventricles_bl 1079
# unique values for Hippocampus_bl 904
# unique values for WholeBrain_bl 1104
# unique values for Entorhinal_bl 847
# unique values for Fusiform_bl 961
# unique values for MidTemp_bl 953
# unique values for ICV_bl 1129
# unique values for MOCA_bl 25
# unique values for EcogPtMem_bl 43
# unique values for EcogPtLang_bl 47
# unique values for EcogPtVisspat_bl 38
# unique values for EcogPtPlan_bl 21
# unique values for EcogPtOrgan_bl 34
# unique values for EcogPtDivatt_bl 15
# unique values for EcogPtTotal_bl 220
# unique values for EcogSPMem_bl 47
# unique values for EcogSPLang_bl 58
# unique values for EcogSPVisspat_bl 45
# unique values for EcogSPPlan_bl 30
# unique values for EcogSPOrgan_bl 35
# unique values for EcogSPDivatt_bl 19
# unique values for EcogSPTotal_bl 319
# unique values for FDG_bl 986
# unique values for AV45_bl 861
# unique values for Years_bl 1556
# unique values for Month_bl 1556
# unique values for Month 24
# unique values for M 23
# unique values for update_stamp 58

# %% [markdown]
# Hi guys, <br>
# I went through all the predictors. It took me a while to go through all the predictors but here below you see their description. <br>
# Here below there is my strategy; I will discuss it with Hsiang and we will implement it <br>
# ** DOUBLE CLICK on it to see it**

# %% [markdown]
#                                                  **STRATEGY**
#
# 'RID',                    They should not be used for prediction, I'd keep them just for merging the prediction?
# 'PTID',                   They should not be used for prediction, I'd keep them just for merging the prediction?
# 'VISCODE'                 They should not be used for prediction, I'd keep them just for merging the prediction?        'SITE'                    Shall we discard for the prediction?
# 'COLPROT'                 Shall we discard for the prediction?
# 'ORIGPROT'                Shall we discard for the prediction?
# 'EXAMDATE'                Shall we discard for the prediction?
# 'DX_bl'                   Hotone, categorical
# 'AGE',                    OK, int
# 'PTGENDER'                Hotone, categorical
# 'PTEDUCAT'                OK, int
# 'PTETHCAT',               Hotone, categorical
# 'PTRACCAT',               Hotone, categorical
# 'PTMARRY'                 Hotone, categorical
# 'APOE4'                   Hotone, categorical   Class of protein
# 'CDRSB'                   OK,float              Clinical Dementia Rating Scale–Sum of Boxes
# 'ADAS11'                  OK,float              Alzheimer's Disease Assessment Scale-Cognitive Subscale
# 'ADAS13'                  OK,float              Alzheimer's Disease Assessment Scale-Cognitive Subscale
# 'MMSE',                   OK,float              Mini Mental State Examination
# 'RAVLT_immediate'         OK,float              Rey Auditory Verbal Learning Test
# 'RAVLT_learning'          OK,float              Rey Auditory Verbal Learning Test
# 'RAVLT_forgetting',       OK,float              Rey Auditory Verbal Learning Test
# 'RAVLT_perc_forgetting'   OK,float              Rey Auditory Verbal Learning Test
# 'FAQ'                     OK,float              Functional Assessment Questionnaire
# 'MOCA'                    OK,float              Montreal Cognitive Assessment (MoCA)
# 'EcogPtMem'               OK,float              Cognitive
# 'EcogPtLang',             OK,float              Cognitive
# 'EcogPtVisspat'           OK,float              Cognitive
# 'EcogPtPlan'              OK,float              Cognitive
# 'EcogPtOrgan'             OK,float              Cognitive
# 'EcogPtDivatt'            OK,float              Cognitive
# 'EcogPtTotal'             OK,float              Cognitive
# 'EcogSPMem'               OK,float              Cognitive
# 'EcogSPLang'              OK,float              Cognitive
# 'EcogSPVisspat'           OK,float              Cognitive
# 'EcogSPPlan',             OK,float              Cognitive
# 'EcogSPOrgan'             OK,float              Cognitive
# 'EcogSPDivatt'            OK,float              Cognitive
# 'EcogSPTotal'             OK,float              Cognitive
# 'FSVERSION',              Just one value, discard
# 'Hippocampus'             OK,float              Hippocampus volume
# 'WholeBrain'              OK,float              Brain volume
# 'ICV'                     OK,float              Intracranial volume
# 'DX'                      OUR Y, ENCODING
# 'EXAMDATE_bl'             Shall we discard for the prediction?
# 'CDRSB_bl'                       ***FROM HERE BASELINE***
# 'ADAS11_bl'
# 'ADAS13_bl'
# 'MMSE_bl'
# 'RAVLT_immediate_bl'
# 'RAVLT_learning_bl'
# 'RAVLT_forgetting_bl'
# 'RAVLT_perc_forgetting_bl',
# 'FAQ_bl', 'FLDSTRENG_bl'
# 'FSVERSION_bl'
# 'Ventricles_bl',
# 'Hippocampus_bl'
# 'WholeBrain_bl'
# 'Entorhinal_bl'
# 'Fusiform_bl',
# 'MidTemp_bl'
# 'ICV_bl'
# 'MOCA_bl'
# 'EcogPtMem_bl'
# 'EcogPtLang_bl',
# 'EcogPtVisspat_bl'
# 'EcogPtPlan_bl'
# 'EcogPtOrgan_bl',
# 'EcogPtDivatt_bl'
# 'EcogPtTotal_bl'
# 'EcogSPMem_bl'
# 'EcogSPLang_bl',
# 'EcogSPVisspat_bl'
# 'EcogSPPlan_bl'
# 'EcogSPOrgan_bl',
# 'EcogSPDivatt_bl'
# 'EcogSPTotal_bl'
# 'FDG_bl'                   OK,float               fluorescence connect to PET
# 'AV45_bl'                  OK,float               average survival
# 'Years_bl',                OK,float               years form baseline
# 'Month_bl'                 Shall we discard for the prediction? We already have 'Years_bl'
# 'Month'                    Shall we discard for the prediction? We already have 'Years_bl'
# 'M'                        Shall we discard for the prediction? We already have 'Years_bl'
# 'update_stamp              Shall we discard for the prediction?

# %%
#Drop columns
print(ADNI2_clean.shape)
ADNI2_clean.drop (['M','Month', 'Month_bl','update_stamp',
                                'FSVERSION', 'EXAMDATE','ORIGPROT' ,
                                'COLPROT', 'SITE','ORIGPROT'], axis =1, inplace= True)
# Out:
# (6690, 85)

# %%
ADNI2_clean['EcogSPTotal_bl'].unique()
# Out:
# array([ 1.25641,  1.25   ,  1.37838,  1.05128,  2.83333,  1.17949,
#         1.     ,  1.12821,      nan,  1.10256,  1.4375 ,  1.02564,
#         2.05882,  2.     ,  3.42857,  1.48718,  1.30769,  1.20513,
#         3.4359 ,  1.46154,  1.54054,  1.92308,  1.72222,  1.15385,
#         2.33333,  3.55263,  1.51282,  3.76923,  1.19444,  1.61538,
#         2.64103,  1.76923,  1.29167,  1.02632,  1.07692,  1.48649,
#         1.42105,  1.44737,  1.97297,  1.18421,  3.30556,  2.12821,
#         1.75758,  3.5    ,  1.86111,  1.86486,  1.59459,  2.51282,
#         1.94872,  2.53846,  2.91667,  3.08108,  2.24324,  2.85714,
#         1.42857,  1.58065,  2.23684,  1.17143,  1.37931,  1.08   ,
#         2.08571,  2.13514,  2.10526,  1.75676,  2.31579,  1.94444,
#         1.38235,  1.52941,  1.23529,  2.41026,  1.80556,  1.87879,
#         2.7027 ,  1.08571,  1.88235,  2.05263,  2.3871 ,  1.97368,
#         1.81081,  1.84211])

# %% [markdown]
# 'AGE'
# 'PTEDUCAT'
# 'PTETHCAT',               Hotone, categorical
# 'PTRACCAT',               Hotone, categorical
# 'PTMARRY'

# %%
#Hot one encoding
#categorical_columns_g2cols = ['DX_bl', 'PTGENDER', 'PTETHCAT','PTRACCAT','PTMARRY','APOE4']                                 
#ADNI2_clean = pd.get_dummies(ADNI2_clean, columns=categorical_columns_g2cols, prefix = categorical_columns_g2cols , drop_first=True)

# %%
print(ADNI2_clean.columns)
# Out:
# Index(['RID', 'PTID', 'VISCODE', 'DX_bl', 'AGE', 'PTGENDER', 'PTEDUCAT',
#        'PTETHCAT', 'PTRACCAT', 'PTMARRY', 'APOE4', 'CDRSB', 'ADAS11', 'ADAS13',
#        'MMSE', 'RAVLT_immediate', 'RAVLT_learning', 'RAVLT_forgetting',
#        'RAVLT_perc_forgetting', 'FAQ', 'MOCA', 'EcogPtMem', 'EcogPtLang',
#        'EcogPtVisspat', 'EcogPtPlan', 'EcogPtOrgan', 'EcogPtDivatt',
#        'EcogPtTotal', 'EcogSPMem', 'EcogSPLang', 'EcogSPVisspat', 'EcogSPPlan',
#        'EcogSPOrgan', 'EcogSPDivatt', 'EcogSPTotal', 'Hippocampus',
#        'WholeBrain', 'ICV', 'DX', 'EXAMDATE_bl', 'CDRSB_bl', 'ADAS11_bl',
#        'ADAS13_bl', 'MMSE_bl', 'RAVLT_immediate_bl', 'RAVLT_learning_bl',
#        'RAVLT_forgetting_bl', 'RAVLT_perc_forgetting_bl', 'FAQ_bl',
#        'FLDSTRENG_bl', 'FSVERSION_bl', 'Ventricles_bl', 'Hippocampus_bl',
#        'WholeBrain_bl', 'Entorhinal_bl', 'Fusiform_bl', 'MidTemp_bl', 'ICV_bl',
#        'MOCA_bl', 'EcogPtMem_bl', 'EcogPtLang_bl', 'EcogPtVisspat_bl',
#        'EcogPtPlan_bl', 'EcogPtOrgan_bl', 'EcogPtDivatt_bl', 'EcogPtTotal_bl',
#        'EcogSPMem_bl', 'EcogSPLang_bl', 'EcogSPVisspat_bl', 'EcogSPPlan_bl',
#        'EcogSPOrgan_bl', 'EcogSPDivatt_bl', 'EcogSPTotal_bl', 'FDG_bl',
#        'AV45_bl', 'Years_bl'],
#       dtype='object')

# %%
#Function to split the data in train and test
def split (data, percentage):
    np.random.seed(9001) 
    msk = np.random.rand(len(data)) < percentage
    train = data[msk]
    test = data[~msk]
    return train, test

# %%
# Imputation by mean

# %%
# Imputation by model
